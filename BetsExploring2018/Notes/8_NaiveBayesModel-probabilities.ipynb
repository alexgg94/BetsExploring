# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql.functions import isnan, when, count, col
#from pyspark.ml.regression import LabeledPoint
from pyspark.ml.classification import NaiveBayes
from pyspark.ml.classification import NaiveBayesModel
from pyspark.ml.linalg import Vector, SparseVector, DenseVector, Matrices
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from random import shuffle
import matplotlib.pyplot as plt

# %%
spark = SparkSession.builder.appName("BetsExploring").getOrCreate()
sc = spark.sparkContext
sc
# Out:
# <SparkContext master=local[*] appName=BetsExploring>

# %%
betsHouses = ['B365', 'BS', 'BW', 'GB', 'IW', 'LB', 'SB', 'SJ', 'VC', 'WH']
quotaTypes = ['H','D','A']

# %%
# Selecting fields included in dataframe to use as features

def calcBetsHousesCols(df, betsHouses):
    betsHousesCols = []
    betsHousesOk = []
    for betsHouse in betsHouses:
        col = betsHouse + 'H'
        if col in df.columns:
            betsHousesOk.append(betsHouse)
            betsHousesCols.append(betsHouse + 'H')
            betsHousesCols.append(betsHouse + 'D')
            betsHousesCols.append(betsHouse + 'A')

    print ("Potential bets houses:", betsHouses)
    print ("Bets houses selected :" , betsHousesOk)
    print ("Bets houses columns  :", betsHousesCols)
    
    return betsHousesCols

# %%
# Cleaning nulls in dataframe, mixing deletion of columns and rows
# Columns with less than 'percDropping' not null rows will be deleted
# Rows with nulls aftes deleting columns will be deleted

def cleanNulls(df, percDropping):
    print ("Cleaning nulls:")
    totalrows = df.count()
    notnullrows = df.dropna().count()
    dropCols = []
    print ("Total rows:", totalrows)
    print ("Not null rows: ", notnullrows)
    print ("Percentage for dropping column: ", percDropping, "%")

    print ("\nNot null rows before cleaning:")
    dfok = df
    for col in df.columns:

        percOk = round((df.select(col).dropna().count() / totalrows) * 100, 2)
        print (col, "\t", df.select(col).dropna().count(), "\t(", percOk, "%)")

        # Dropping columnss with a lot of nulls
        if percOk < percDropping:
            dropCols.append(col)
            dfok = dfok.drop(col)
    #        print ("\tColumn dropped")

    # Dropping row with nulls
    dfok = dfok.dropna()
    percOk = round((dfok.count() / totalrows) * 100 , 2)
    print ("\nDropped columns:", dropCols)
    print ("Not null rows after cleaning: " , dfok.count(), "\t(", percOk, "%)")
    print ("Final columns:", dfok.columns)
    
    return dfok

# %%
# Converting text result to numeric result

def resultToNumeric(df):
    dfok = df.withColumn("Label", when(df['FTR']=='H',0)
                             .when(df['FTR']=='D',1)
                             .when(df['FTR']=='A',2).cast("double"))
    dfok.show(3)
                      
    return dfok

# %%
# Create Dataframe with label and features 

def createLabelAndFeatures(df, betsHousesCols):
    vectorAssembler = VectorAssembler(
        inputCols = betsHousesCols, 
        outputCol = 'features')

    vec_df = vectorAssembler.transform(df)

    vec_df = vec_df.withColumn("label", df["Label"])

    vec_df = vec_df.select(['features', 'label'])
    vec_df.show(5, False)
    vec_df.printSchema()
    
    return vec_df

# %%
# Defining, Training and Avaluating Naive Bayes Model

def calcNaiveBayesModel(df, betsHousesCols):
    
    # Converting result to numeric
    print ("\n  - Converting result to numeric")
    df = resultToNumeric(df)

    # Creating vector with label and features for training
    print ("\n  - Creating vector with label and features for training")
    vectrain = createLabelAndFeatures(df, betsHousesCols)

    # Training model
    print ("\n  - Training model")
    nb = NaiveBayes(smoothing=1.0, modelType="multinomial")
    model = nb.fit(vectrain)
    print("Pi   :", model.pi)
    print("Theta:", model.theta)

    # Calculating auto-prediction to avaluate model
    print ("\n  - Calculating auto-prediction to avaluate model")
    predict_train = model.transform(vectrain)
    predict_train.show(5, False)

    # Evaluating model
    print ("\n  - Evaluating model")
    nb_evaluator = MulticlassClassificationEvaluator(predictionCol="prediction",labelCol="label",metricName="accuracy")
    results = nb_evaluator.evaluate(predict_train)
    print ("Accuracy: ", round(results * 100, 2), "%")
    
    return model

# %%
# Calculating predictions with test dataset
def calcPrediction (model, df, betsHousesCols):
    
    # Converting result to numeric
    print ("\n  - Converting result to numeric")
    df = resultToNumeric(df)

    # Creating vector with label and features for training
    print ("  - Creating vector with label and features for training")
    vectest = createLabelAndFeatures(df, betsHousesCols)

    # Calculating prediction
    print ("  - Calculating prediction")
    predict = model.transform(vectest)
    print(predict.count())
    predict.show(5, False)

    # Evaluating test
    print ("  - Evaluating model")
    nb_evaluator = MulticlassClassificationEvaluator(predictionCol="prediction",labelCol="label",metricName="accuracy")
    results = nb_evaluator.evaluate(predict)
    print ("Accuracy: ", round(results * 100, 2), "%")
    
    return predict

# %%
# Calculating Naive Bayes Model and Prediction

def calcModelAndPrediction(df):
    
    # Cleaning nulls in columns and rows
    print ("\n* Cleaning nulls in columns and rows")
    dfok = cleanNulls(df, 80)

    # Calculating Bets Houses Cols
    print ("\n  - Calculating Bets Houses Cols")
    betsHousesCols =  calcBetsHousesCols(dfok, betsHouses)

    # Spliting training and testing datasets
    print ("\n* Spliting training and testing datasets")
    dftrain, dftest = dfok.randomSplit([0.8, 0.2], seed=1)
    print("  Train dataset:", dftrain.count(), "rows")
    print("  Test dataset: ", dftest.count(), "rows")

    # Defining, Training and Avaluating Naive Bayes Model
    print ("\n* Defining, Training and Avaluating Naive Bayes Model")
    model = calcNaiveBayesModel(dftrain, betsHousesCols)

    # Calculating predictions with test dataset
    print ("\n* Calculating predictions with test dataset")
    predict = calcPrediction(model, dftest, betsHousesCols)

# %%
url = "../Data/Processed/main_competitions_recent.csv"
# Open Dataset file
print ("* Opening dataset file")
df = spark.read.csv(path = url, header = True, inferSchema = True)
print ("Rows   :", df.count())
print ("Columns:", df.columns)
print ("First row:")
print(df.take(1))
df.printSchema()

calcModelAndPrediction(df)
# Out:
# * Opening dataset file
# Rows   : 11374
# Columns: ['Country', 'Competition', 'Season', 'Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'VCH', 'VCD', 'VCA', 'WHH', 'WHD', 'WHA']
# First row:
# [Row(Country='Belgium', Competition='JupilerLeague', Season='2017-2018', Div='B1', Date=datetime.datetime(2017, 7, 28, 0, 0), HomeTeam='Antwerp', AwayTeam='Anderlecht', FTR='D', B365H=5.75, B365D=3.8, B365A=1.6, BWH=5.0, BWD=4.0, BWA=1.67, IWH=4.7, IWD=3.6, IWA=1.7, LBH=5.2, LBD=3.7, LBA=1.61, VCH=5.5, VCD=3.9, VCA=1.62, WHH=4.75, WHD=3.75, WHA=1.67)]
# root
#  |-- Country: string (nullable = true)
#  |-- Competition: string (nullable = true)
#  |-- Season: string (nullable = true)
#  |-- Div: string (nullable = true)
#  |-- Date: timestamp (nullable = true)
#  |-- HomeTeam: string (nullable = true)
#  |-- AwayTeam: string (nullable = true)
#  |-- FTR: string (nullable = true)
#  |-- B365H: double (nullable = true)
#  |-- B365D: double (nullable = true)
#  |-- B365A: double (nullable = true)
#  |-- BWH: double (nullable = true)
#  |-- BWD: double (nullable = true)
#  |-- BWA: double (nullable = true)
#  |-- IWH: double (nullable = true)
#  |-- IWD: double (nullable = true)
#  |-- IWA: double (nullable = true)
#  |-- LBH: double (nullable = true)
#  |-- LBD: double (nullable = true)
#  |-- LBA: double (nullable = true)
#  |-- VCH: double (nullable = true)
#  |-- VCD: double (nullable = true)
#  |-- VCA: double (nullable = true)
#  |-- WHH: double (nullable = true)
#  |-- WHD: double (nullable = true)
#  |-- WHA: double (nullable = true)
#
#
# * Cleaning nulls in columns and rows
# Cleaning nulls:
# Total rows: 11374
# Not null rows:  7668
# Percentage for dropping column:  80 %
#
# Not null rows before cleaning:
# Country 	 11374 	( 100.0 %)
# Competition 	 11374 	( 100.0 %)
# Season 	 11374 	( 100.0 %)
# Div 	 11374 	( 100.0 %)
# Date 	 11374 	( 100.0 %)
# HomeTeam 	 11374 	( 100.0 %)
# AwayTeam 	 11374 	( 100.0 %)
# FTR 	 11374 	( 100.0 %)
# B365H 	 11360 	( 99.88 %)
# B365D 	 11360 	( 99.88 %)
# B365A 	 11360 	( 99.88 %)
# BWH 	 11362 	( 99.89 %)
# BWD 	 11362 	( 99.89 %)
# BWA 	 11362 	( 99.89 %)
# IWH 	 11344 	( 99.74 %)
# IWD 	 11344 	( 99.74 %)
# IWA 	 11340 	( 99.7 %)
# LBH 	 7694 	( 67.65 %)
# LBD 	 7694 	( 67.65 %)
# LBA 	 7698 	( 67.68 %)
# VCH 	 11356 	( 99.84 %)
# VCD 	 11356 	( 99.84 %)
# VCA 	 11356 	( 99.84 %)
# WHH 	 11358 	( 99.86 %)
# WHD 	 11358 	( 99.86 %)
# WHA 	 11358 	( 99.86 %)
#
# Dropped columns: ['LBH', 'LBD', 'LBA']
# Not null rows after cleaning:  11304 	( 99.38 %)
# Final columns: ['Country', 'Competition', 'Season', 'Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'VCH', 'VCD', 'VCA', 'WHH', 'WHD', 'WHA']
#
#   - Calculating Bets Houses Cols
# Potential bets houses: ['B365', 'BS', 'BW', 'GB', 'IW', 'LB', 'SB', 'SJ', 'VC', 'WH']
# Bets houses selected : ['B365', 'BW', 'IW', 'VC', 'WH']
# Bets houses columns  : ['B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'VCH', 'VCD', 'VCA', 'WHH', 'WHD', 'WHA']
#
# * Spliting training and testing datasets
#   Train dataset: 8973 rows
#   Test dataset:  2331 rows
#
# * Defining, Training and Avaluating Naive Bayes Model
#
#   - Converting result to numeric
# +-------+-------------+---------+---+-------------------+-----------+--------+---+-----+-----+-----+----+---+---+----+---+---+----+---+---+----+---+----+-----+
# |Country|  Competition|   Season|Div|               Date|   HomeTeam|AwayTeam|FTR|B365H|B365D|B365A| BWH|BWD|BWA| IWH|IWD|IWA| VCH|VCD|VCA| WHH|WHD| WHA|Label|
# +-------+-------------+---------+---+-------------------+-----------+--------+---+-----+-----+-----+----+---+---+----+---+---+----+---+---+----+---+----+-----+
# |Belgium|JupilerLeague|2017-2018| B1|2017-01-10 00:00:00| Anderlecht|Standard|  H| 1.62|  4.0|  5.0| 1.6|3.8|5.5| 1.7|3.7|4.5|1.65|4.0|5.0|1.62|3.8| 5.0|  0.0|
# |Belgium|JupilerLeague|2017-2018| B1|2017-01-10 00:00:00|Club Brugge|    Gent|  H|  1.7|  3.6|  5.0| 1.7|3.6|5.0| 1.7|3.7|4.5|1.75|3.8|4.4|1.75|3.6|4.33|  0.0|
# |Belgium|JupilerLeague|2017-2018| B1|2017-01-10 00:00:00|    Waregem| Lokeren|  A| 1.53|  4.0| 6.25|1.57|4.0|5.5|1.55|4.0|5.5|1.57|4.2|5.4|1.62|3.8| 5.0|  2.0|
# +-------+-------------+---------+---+-------------------+-----------+--------+---+-----+-----+-----+----+---+---+----+---+---+----+---+---+----+---+----+-----+
# only showing top 3 rows
#
#
#   - Creating vector with label and features for training
# +-------------------------------------------------------------------+-----+
# |features                                                           |label|
# +-------------------------------------------------------------------+-----+
# |[1.62,4.0,5.0,1.6,3.8,5.5,1.7,3.7,4.5,1.65,4.0,5.0,1.62,3.8,5.0]   |0.0  |
# |[1.7,3.6,5.0,1.7,3.6,5.0,1.7,3.7,4.5,1.75,3.8,4.4,1.75,3.6,4.33]   |0.0  |
# |[1.53,4.0,6.25,1.57,4.0,5.5,1.55,4.0,5.5,1.57,4.2,5.4,1.62,3.8,5.0]|2.0  |
# |[1.9,3.6,3.75,1.91,3.5,4.1,1.9,3.45,3.8,2.0,3.5,3.6,2.0,3.4,3.5]   |1.0  |
# |[7.0,4.0,1.5,5.75,4.1,1.57,5.5,4.0,1.55,5.75,4.1,1.55,6.0,3.8,1.53]|2.0  |
# +-------------------------------------------------------------------+-----+
# only showing top 5 rows
#
# root
#  |-- features: vector (nullable = true)
#  |-- label: double (nullable = true)
#
#
#   - Training model
# Pi   : [-0.824643466911,-1.32787411746,-1.21547662881]
# Theta: DenseMatrix([[-3.2531795 , -2.64402429, -2.36243739, -3.26665357, -2.66057714,
#               -2.39315345, -3.27782149, -2.69446288, -2.45040114, -3.24816115,
#               -2.62881041, -2.33001236, -3.26201643, -2.67184672, -2.41448805],
#              [-2.96478428, -2.6101748 , -2.54048622, -2.98352853, -2.62748511,
#               -2.56973434, -2.99983881, -2.6517907 , -2.61021806, -2.9586107 ,
#               -2.60021446, -2.53892467, -2.98065205, -2.63281479, -2.58926739],
#              [-2.68547974, -2.60777643, -2.78171451, -2.713572  , -2.62379914,
#               -2.8032836 , -2.75257048, -2.65026367, -2.8330401 , -2.67434483,
#               -2.59566017, -2.78117667, -2.71609587, -2.62931028, -2.81776784]])
#
#   - Calculating auto-prediction to avaluate model
# +-------------------------------------------------------------------+-----+-------------------------------------------------------------+---------------------------------------------------------------+----------+
# |features                                                           |label|rawPrediction                                                |probability                                                    |prediction|
# +-------------------------------------------------------------------+-----+-------------------------------------------------------------+---------------------------------------------------------------+----------+
# |[1.62,4.0,5.0,1.6,3.8,5.5,1.7,3.7,4.5,1.65,4.0,5.0,1.62,3.8,5.0]   |0.0  |[-138.58556920219803,-140.57979402076523,-144.05135620671567]|[0.8769251804381182,0.11936629290156024,0.0037085266603216634] |0.0       |
# |[1.7,3.6,5.0,1.7,3.6,5.0,1.7,3.7,4.5,1.75,3.8,4.4,1.75,3.6,4.33]   |0.0  |[-133.05921947323003,-134.63947154002267,-137.58696199164368]|[0.8218762239795288,0.16924336993589081,0.008880406084580484]  |0.0       |
# |[1.53,4.0,6.25,1.57,4.0,5.5,1.55,4.0,5.5,1.57,4.2,5.4,1.62,3.8,5.0]|2.0  |[-145.64492652064752,-148.1792657317731,-152.36304757976566] |[0.9254778239647202,0.07340345163102341,0.0011187244042562482] |0.0       |
# |[1.9,3.6,3.75,1.91,3.5,4.1,1.9,3.45,3.8,2.0,3.5,3.6,2.0,3.4,3.5]   |1.0  |[-123.72607481318903,-124.21567636206096,-125.81561130677355]|[0.5758328625130401,0.35291099998937064,0.07125613749758919]   |0.0       |
# |[7.0,4.0,1.5,5.75,4.1,1.57,5.5,4.0,1.55,5.75,4.1,1.55,6.0,3.8,1.53]|2.0  |[-170.25537121328023,-162.90577938669531,-156.44033989543217]|[9.989237234588793E-7,0.0015538872450966545,0.9984451138311798]|2.0       |
# +-------------------------------------------------------------------+-----+-------------------------------------------------------------+---------------------------------------------------------------+----------+
# only showing top 5 rows
#
#
#   - Evaluating model
# Accuracy:  48.16 %
#
# * Calculating predictions with test dataset
#
#   - Converting result to numeric
# +-------+-------------+---------+---+-------------------+--------+----------------+---+-----+-----+-----+----+----+----+----+---+---+----+----+----+----+---+---+-----+
# |Country|  Competition|   Season|Div|               Date|HomeTeam|        AwayTeam|FTR|B365H|B365D|B365A| BWH| BWD| BWA| IWH|IWD|IWA| VCH| VCD| VCA| WHH|WHD|WHA|Label|
# +-------+-------------+---------+---+-------------------+--------+----------------+---+-----+-----+-----+----+----+----+----+---+---+----+----+----+----+---+---+-----+
# |Belgium|JupilerLeague|2017-2018| B1|2017-02-12 00:00:00|Kortrijk|Waasland-Beveren|  H|  2.6|  3.5| 2.54|2.55| 3.5| 2.7|2.85|3.4|2.3|2.55| 3.5|2.63| 2.5|3.4|2.6|  0.0|
# |Belgium|JupilerLeague|2017-2018| B1|2017-03-12 00:00:00|Standard|         Antwerp|  D| 1.53| 3.79|  6.5|1.57| 4.1| 6.0|1.55|4.0|5.5|1.53| 4.1| 6.0|1.53|3.8|6.0|  1.0|
# |Belgium|JupilerLeague|2017-2018| B1|2017-05-08 00:00:00|Mouscron|       Charleroi|  A|  3.3| 3.25|  2.2| 3.2|3.25|2.35| 2.9|3.3|2.3|3.13|3.25| 2.3| 3.2|3.2|2.2|  2.0|
# +-------+-------------+---------+---+-------------------+--------+----------------+---+-----+-----+-----+----+----+----+----+---+---+----+----+----+----+---+---+-----+
# only showing top 3 rows
#
#   - Creating vector with label and features for training
# +--------------------------------------------------------------------+-----+
# |features                                                            |label|
# +--------------------------------------------------------------------+-----+
# |[2.6,3.5,2.54,2.55,3.5,2.7,2.85,3.4,2.3,2.55,3.5,2.63,2.5,3.4,2.6]  |0.0  |
# |[1.53,3.79,6.5,1.57,4.1,6.0,1.55,4.0,5.5,1.53,4.1,6.0,1.53,3.8,6.0] |1.0  |
# |[3.3,3.25,2.2,3.2,3.25,2.35,2.9,3.3,2.3,3.13,3.25,2.3,3.2,3.2,2.2]  |2.0  |
# |[1.75,3.75,4.33,1.83,3.7,4.25,1.85,3.5,3.9,1.87,3.6,4.0,1.8,3.5,4.2]|0.0  |
# |[1.4,4.5,8.0,1.42,4.6,7.75,1.4,4.4,7.3,1.4,4.8,7.5,1.4,4.5,7.0]     |0.0  |
# +--------------------------------------------------------------------+-----+
# only showing top 5 rows
#
# root
#  |-- features: vector (nullable = true)
#  |-- label: double (nullable = true)
#
#   - Calculating prediction
# 2331
# +--------------------------------------------------------------------+-----+-------------------------------------------------------------+---------------------------------------------------------------+----------+
# |features                                                            |label|rawPrediction                                                |probability                                                    |prediction|
# +--------------------------------------------------------------------+-----+-------------------------------------------------------------+---------------------------------------------------------------+----------+
# |[2.6,3.5,2.54,2.55,3.5,2.7,2.85,3.4,2.3,2.55,3.5,2.63,2.5,3.4,2.6]  |0.0  |[-119.90854343337756,-118.39424430490911,-117.7089577548774] |[0.06864591746757903,0.31208038227510093,0.61927370025732]     |2.0       |
# |[1.53,3.79,6.5,1.57,4.1,6.0,1.55,4.0,5.5,1.53,4.1,6.0,1.53,3.8,6.0] |1.0  |[-150.269031702116,-153.27986388921582,-158.0503502714462]   |[0.9526820568137405,0.046920235239363436,3.977079468959337E-4] |0.0       |
# |[3.3,3.25,2.2,3.2,3.25,2.35,2.9,3.3,2.3,3.13,3.25,2.3,3.2,3.2,2.2]  |2.0  |[-122.47762964443216,-119.97339437564986,-118.2231060276952] |[0.011953506561771942,0.14624158415945754,0.8418049092787705]  |2.0       |
# |[1.75,3.75,4.33,1.83,3.7,4.25,1.85,3.5,3.9,1.87,3.6,4.0,1.8,3.5,4.2]|0.0  |[-127.92809161296766,-128.92247140169374,-131.14022669617728]|[0.7091075260790759,0.26233633059888606,0.02855614332203803]   |0.0       |
# |[1.4,4.5,8.0,1.42,4.6,7.75,1.4,4.4,7.3,1.4,4.8,7.5,1.4,4.5,7.0]     |0.0  |[-174.06581823207821,-178.51944742050904,-185.22888794778058]|[0.9884837211210639,0.011502253650521944,1.4025228414161577E-5]|0.0       |
# +--------------------------------------------------------------------+-----+-------------------------------------------------------------+---------------------------------------------------------------+----------+
# only showing top 5 rows
#
#   - Evaluating model
# Accuracy:  48.05 %

# %%
url = "../Data/Processed/main_competitions.csv"
# Open Dataset file
print ("* Opening dataset file")
df = spark.read.csv(path = url, header = True, inferSchema = True)
print ("Rows   :", df.count())
print ("Columns:", df.columns)
print ("First row:")
print(df.take(1))
df.printSchema()

calcModelAndPrediction(df)
# Out:
# * Opening dataset file
# Rows   : 106583
# Columns: ['Country', 'Competition', 'Season', 'Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTR', 'B365H', 'B365D', 'B365A', 'BSH', 'BSD', 'BSA', 'BWH', 'BWD', 'BWA', 'GBH', 'GBD', 'GBA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'SBH', 'SBD', 'SBA', 'SJH', 'SJD', 'SJA', 'VCH', 'VCD', 'VCA', 'WHH', 'WHD', 'WHA']
# First row:
# [Row(Country='Belgium', Competition='JupilerLeague', Season='2003-2004', Div='B1', Date=datetime.datetime(2003, 8, 8, 0, 0), HomeTeam='Club Brugge', AwayTeam='Genk', FTR='H', B365H=1.4, B365D=3.75, B365A=7.0, BSH=None, BSD=None, BSA=None, BWH=None, BWD=None, BWA=None, GBH=1.4, GBD=3.8, GBA=6.85, IWH=1.45, IWD=3.8, IWA=5.4, LBH=None, LBD=None, LBA=None, SBH=1.44, SBD=3.75, SBA=6.5, SJH=None, SJD=None, SJA=None, VCH=None, VCD=None, VCA=None, WHH=None, WHD=None, WHA=None)]
# root
#  |-- Country: string (nullable = true)
#  |-- Competition: string (nullable = true)
#  |-- Season: string (nullable = true)
#  |-- Div: string (nullable = true)
#  |-- Date: timestamp (nullable = true)
#  |-- HomeTeam: string (nullable = true)
#  |-- AwayTeam: string (nullable = true)
#  |-- FTR: string (nullable = true)
#  |-- B365H: double (nullable = true)
#  |-- B365D: double (nullable = true)
#  |-- B365A: double (nullable = true)
#  |-- BSH: double (nullable = true)
#  |-- BSD: double (nullable = true)
#  |-- BSA: double (nullable = true)
#  |-- BWH: double (nullable = true)
#  |-- BWD: double (nullable = true)
#  |-- BWA: double (nullable = true)
#  |-- GBH: double (nullable = true)
#  |-- GBD: double (nullable = true)
#  |-- GBA: double (nullable = true)
#  |-- IWH: double (nullable = true)
#  |-- IWD: double (nullable = true)
#  |-- IWA: double (nullable = true)
#  |-- LBH: double (nullable = true)
#  |-- LBD: double (nullable = true)
#  |-- LBA: double (nullable = true)
#  |-- SBH: double (nullable = true)
#  |-- SBD: double (nullable = true)
#  |-- SBA: double (nullable = true)
#  |-- SJH: double (nullable = true)
#  |-- SJD: double (nullable = true)
#  |-- SJA: double (nullable = true)
#  |-- VCH: double (nullable = true)
#  |-- VCD: double (nullable = true)
#  |-- VCA: double (nullable = true)
#  |-- WHH: double (nullable = true)
#  |-- WHD: double (nullable = true)
#  |-- WHA: double (nullable = true)
#
#
# * Cleaning nulls in columns and rows
# Cleaning nulls:
# Total rows: 106583
# Not null rows:  34323
# Percentage for dropping column:  80 %
#
# Not null rows before cleaning:
# Country 	 106583 	( 100.0 %)
# Competition 	 106583 	( 100.0 %)
# Season 	 106583 	( 100.0 %)
# Div 	 106583 	( 100.0 %)
# Date 	 106583 	( 100.0 %)
# HomeTeam 	 106583 	( 100.0 %)
# AwayTeam 	 106583 	( 100.0 %)
# FTR 	 106583 	( 100.0 %)
# B365H 	 106322 	( 99.76 %)
# B365D 	 106322 	( 99.76 %)
# B365A 	 106322 	( 99.76 %)
# BSH 	 44825 	( 42.06 %)
# BSD 	 44826 	( 42.06 %)
# BSA 	 44825 	( 42.06 %)
# BWH 	 104027 	( 97.6 %)
# BWD 	 104027 	( 97.6 %)
# BWA 	 104027 	( 97.6 %)
# GBH 	 64214 	( 60.25 %)
# GBD 	 64214 	( 60.25 %)
# GBA 	 64214 	( 60.25 %)
# IWH 	 105208 	( 98.71 %)
# IWD 	 105208 	( 98.71 %)
# IWA 	 105204 	( 98.71 %)
# LBH 	 100939 	( 94.7 %)
# LBD 	 100939 	( 94.7 %)
# LBA 	 100943 	( 94.71 %)
# SBH 	 56297 	( 52.82 %)
# SBD 	 56298 	( 52.82 %)
# SBA 	 56298 	( 52.82 %)
# SJH 	 68687 	( 64.44 %)
# SJD 	 68687 	( 64.44 %)
# SJA 	 68687 	( 64.44 %)
# VCH 	 101884 	( 95.59 %)
# VCD 	 101883 	( 95.59 %)
# VCA 	 101884 	( 95.59 %)
# WHH 	 104203 	( 97.77 %)
# WHD 	 104203 	( 97.77 %)
# WHA 	 104203 	( 97.77 %)
#
# Dropped columns: ['BSH', 'BSD', 'BSA', 'GBH', 'GBD', 'GBA', 'SBH', 'SBD', 'SBA', 'SJH', 'SJD', 'SJA']
# Not null rows after cleaning:  94380 	( 88.55 %)
# Final columns: ['Country', 'Competition', 'Season', 'Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'VCH', 'VCD', 'VCA', 'WHH', 'WHD', 'WHA']
#
#   - Calculating Bets Houses Cols
# Potential bets houses: ['B365', 'BS', 'BW', 'GB', 'IW', 'LB', 'SB', 'SJ', 'VC', 'WH']
# Bets houses selected : ['B365', 'BW', 'IW', 'LB', 'VC', 'WH']
# Bets houses columns  : ['B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'VCH', 'VCD', 'VCA', 'WHH', 'WHD', 'WHA']
#
# * Spliting training and testing datasets
#   Train dataset: 75392 rows
#   Test dataset:  18988 rows
#
# * Defining, Training and Avaluating Naive Bayes Model
#
#   - Converting result to numeric
# +-------+-------------+---------+---+-------------------+-----------+-----------+---+-----+-----+-----+----+---+----+----+---+----+----+----+----+----+---+----+---+---+----+-----+
# |Country|  Competition|   Season|Div|               Date|   HomeTeam|   AwayTeam|FTR|B365H|B365D|B365A| BWH|BWD| BWA| IWH|IWD| IWA| LBH| LBD| LBA| VCH|VCD| VCA|WHH|WHD| WHA|Label|
# +-------+-------------+---------+---+-------------------+-----------+-----------+---+-----+-----+-----+----+---+----+----+---+----+----+----+----+----+---+----+---+---+----+-----+
# |Belgium|JupilerLeague|2005-2006| B1|2005-01-10 00:00:00| Anderlecht| St Truiden|  H|  1.2|  5.5| 10.0| 1.2|5.5|10.5|1.15|6.0|12.0| 1.2| 5.0|11.0|1.15|6.0|11.0|1.2|5.0|11.0|  0.0|
# |Belgium|JupilerLeague|2005-2006| B1|2005-01-10 00:00:00|       Gent|     Lierse|  D| 1.61|  3.4|  5.0| 1.6|3.4|5.25| 1.6|3.4| 4.6|1.61|3.25| 5.0|1.65|3.4|4.35|1.6|3.5| 4.6|  1.0|
# |Belgium|JupilerLeague|2005-2006| B1|2005-01-10 00:00:00|Louvieroise|FC Brussels|  A|  2.1| 3.25|  3.0|2.15|3.1| 3.1| 2.2|3.1| 2.8| 2.0| 3.2| 3.2| 2.1|3.4| 2.9|2.1|3.2| 3.0|  2.0|
# +-------+-------------+---------+---+-------------------+-----------+-----------+---+-----+-----+-----+----+---+----+----+---+----+----+----+----+----+---+----+---+---+----+-----+
# only showing top 3 rows
#
#
#   - Creating vector with label and features for training
# +---------------------------------------------------------------------------------+-----+
# |features                                                                         |label|
# +---------------------------------------------------------------------------------+-----+
# |[1.2,5.5,10.0,1.2,5.5,10.5,1.15,6.0,12.0,1.2,5.0,11.0,1.15,6.0,11.0,1.2,5.0,11.0]|0.0  |
# |[1.61,3.4,5.0,1.6,3.4,5.25,1.6,3.4,4.6,1.61,3.25,5.0,1.65,3.4,4.35,1.6,3.5,4.6]  |1.0  |
# |[2.1,3.25,3.0,2.15,3.1,3.1,2.2,3.1,2.8,2.0,3.2,3.2,2.1,3.4,2.9,2.1,3.2,3.0]      |2.0  |
# |[1.4,4.0,6.5,1.4,4.0,6.75,1.4,3.9,6.0,1.4,3.75,7.0,1.4,4.0,6.5,1.4,4.0,6.2]      |0.0  |
# |[1.72,3.4,4.2,1.85,3.2,3.85,1.8,3.1,3.8,1.72,3.4,4.0,1.8,3.25,4.0,1.75,3.35,3.9] |0.0  |
# +---------------------------------------------------------------------------------+-----+
# only showing top 5 rows
#
# root
#  |-- features: vector (nullable = true)
#  |-- label: double (nullable = true)
#
#
#   - Training model
# Pi   : [-0.800329398575,-1.3236144532,-1.25650362538]
# Theta: DenseMatrix([[-3.39279194, -2.81813193, -2.54221134, -3.41118262, -2.84627728,
#               -2.59633657, -3.42232636, -2.88530288, -2.6642176 , -3.41514504,
#               -2.85288591, -2.59330416, -3.392106  , -2.8131136 , -2.52582306,
#               -3.40356431, -2.85867171, -2.59467789],
#              [-3.14627373, -2.79174922, -2.70354779, -3.17013051, -2.8183405 ,
#               -2.74350009, -3.192323  , -2.84719886, -2.79656947, -3.17754922,
#               -2.81947302, -2.74786864, -3.14469021, -2.79028439, -2.70061072,
#               -3.16450651, -2.82604952, -2.74828586],
#              [-2.93302382, -2.78146809, -2.88197988, -2.96835528, -2.80915219,
#               -2.91428351, -3.00731769, -2.84058556, -2.95330052, -2.97473852,
#               -2.80872206, -2.91728106, -2.92668914, -2.77883081, -2.88051168,
#               -2.96174477, -2.81611062, -2.91614281]])
#
#   - Calculating auto-prediction to avaluate model
# +---------------------------------------------------------------------------------+-----+-------------------------------------------------------------+----------------------------------------------------------------+----------+
# |features                                                                         |label|rawPrediction                                                |probability                                                     |prediction|
# +---------------------------------------------------------------------------------+-----+-------------------------------------------------------------+----------------------------------------------------------------+----------+
# |[1.2,5.5,10.0,1.2,5.5,10.5,1.15,6.0,12.0,1.2,5.0,11.0,1.15,6.0,11.0,1.2,5.0,11.0]|0.0  |[-288.3927996987641,-296.27481711978913,-305.5877923389739]  |[0.9996226376203838,3.7732832737785217E-4,3.4052238198527313E-8]|0.0       |
# |[1.61,3.4,5.0,1.6,3.4,5.25,1.6,3.4,4.6,1.61,3.25,5.0,1.65,3.4,4.35,1.6,3.5,4.6]  |1.0  |[-166.13483169501885,-168.14750176133197,-170.82172313542424]|[0.8750080098049328,0.11692853942633663,0.008063450768730631]   |0.0       |
# |[2.1,3.25,3.0,2.15,3.1,3.1,2.2,3.1,2.8,2.0,3.2,3.2,2.1,3.4,2.9,2.1,3.2,3.0]      |2.0  |[-145.2005292610787,-144.87878453213452,-145.11722394381667] |[0.2884832155811821,0.3979719936009887,0.3135447908178291]      |1.0       |
# |[1.4,4.0,6.5,1.4,4.0,6.75,1.4,3.9,6.0,1.4,3.75,7.0,1.4,4.0,6.5,1.4,4.0,6.2]      |0.0  |[-197.40100671988017,-201.19959632638887,-205.83882351212378]|[0.9778814289837549,0.021906837833263457,2.11733182981686E-4]   |0.0       |
# |[1.72,3.4,4.2,1.85,3.2,3.85,1.8,3.1,3.8,1.72,3.4,4.0,1.8,3.25,4.0,1.75,3.35,3.9] |0.0  |[-154.48900390996494,-155.52526570452017,-157.15147408087756]|[0.7019740463117506,0.2490452576853493,0.04898069600290007]     |0.0       |
# +---------------------------------------------------------------------------------+-----+-------------------------------------------------------------+----------------------------------------------------------------+----------+
# only showing top 5 rows
#
#
#   - Evaluating model
# Accuracy:  47.4 %
#
# * Calculating predictions with test dataset
#
#   - Converting result to numeric
# +-------+-------------+---------+---+-------------------+----------+-----------+---+-----+-----+-----+---+---+----+----+---+---+----+----+---+----+----+---+----+----+----+-----+
# |Country|  Competition|   Season|Div|               Date|  HomeTeam|   AwayTeam|FTR|B365H|B365D|B365A|BWH|BWD| BWA| IWH|IWD|IWA| LBH| LBD|LBA| VCH| VCD|VCA| WHH| WHD| WHA|Label|
# +-------+-------------+---------+---+-------------------+----------+-----------+---+-----+-----+-----+---+---+----+----+---+---+----+----+---+----+----+---+----+----+----+-----+
# |Belgium|JupilerLeague|2005-2006| B1|2005-01-10 00:00:00|   Waregem|  Roeselare|  H| 1.66|  3.4|  4.5|1.8|3.2|4.05|1.75|3.2|4.0|1.72| 3.4|4.0| 1.7| 3.6|4.0| 1.6| 3.5| 4.6|  0.0|
# |Belgium|JupilerLeague|2005-2006| B1|2005-03-12 00:00:00|    Lierse|FC Brussels|  D|  2.5|  3.2|  2.5|2.5|3.2| 2.5| 2.6|3.0|2.4|2.38| 3.2|2.6|2.35|3.25|2.5|2.45|3.25|2.45|  1.0|
# |Belgium|JupilerLeague|2005-2006| B1|2005-05-11 00:00:00|Anderlecht|  Charleroi|  H|  1.3|  4.5|  8.5|1.3|4.5| 8.5|1.27|4.3|8.5|1.29|4.33|9.0|1.28| 4.5|8.0|1.28| 4.5| 8.0|  0.0|
# +-------+-------------+---------+---+-------------------+----------+-----------+---+-----+-----+-----+---+---+----+----+---+---+----+----+---+----+----+---+----+----+----+-----+
# only showing top 3 rows
#
#   - Creating vector with label and features for training
# +--------------------------------------------------------------------------------+-----+
# |features                                                                        |label|
# +--------------------------------------------------------------------------------+-----+
# |[1.66,3.4,4.5,1.8,3.2,4.05,1.75,3.2,4.0,1.72,3.4,4.0,1.7,3.6,4.0,1.6,3.5,4.6]   |0.0  |
# |[2.5,3.2,2.5,2.5,3.2,2.5,2.6,3.0,2.4,2.38,3.2,2.6,2.35,3.25,2.5,2.45,3.25,2.45] |1.0  |
# |[1.3,4.5,8.5,1.3,4.5,8.5,1.27,4.3,8.5,1.29,4.33,9.0,1.28,4.5,8.0,1.28,4.5,8.0]  |0.0  |
# |[1.53,3.5,6.0,1.6,3.4,5.25,1.5,3.7,5.0,1.44,3.6,6.5,1.45,3.75,6.0,1.5,3.6,5.5]  |0.0  |
# |[1.25,4.5,10.0,1.25,5.0,9.0,1.25,4.5,9.0,1.2,5.0,11.0,1.22,5.0,9.0,1.22,5.0,9.5]|0.0  |
# +--------------------------------------------------------------------------------+-----+
# only showing top 5 rows
#
# root
#  |-- features: vector (nullable = true)
#  |-- label: double (nullable = true)
#
#   - Calculating prediction
# 18988
# +--------------------------------------------------------------------------------+-----+-------------------------------------------------------------+----------------------------------------------------------------+----------+
# |features                                                                        |label|rawPrediction                                                |probability                                                     |prediction|
# +--------------------------------------------------------------------------------+-----+-------------------------------------------------------------+----------------------------------------------------------------+----------+
# |[1.66,3.4,4.5,1.8,3.2,4.05,1.75,3.2,4.0,1.72,3.4,4.0,1.7,3.6,4.0,1.6,3.5,4.6]   |0.0  |[-158.42698526194545,-159.75732680525357,-161.69825504043945]|[0.7678456086854412,0.20300835569884348,0.029146035615715486]   |0.0       |
# |[2.5,3.2,2.5,2.5,3.2,2.5,2.6,3.0,2.4,2.38,3.2,2.6,2.35,3.25,2.5,2.45,3.25,2.45] |1.0  |[-144.14569780646633,-142.8482495277485,-142.13540055085986] |[0.08247094992898578,0.3018391887517542,0.6156898613192601]     |2.0       |
# |[1.3,4.5,8.5,1.3,4.5,8.5,1.27,4.3,8.5,1.29,4.33,9.0,1.28,4.5,8.0,1.28,4.5,8.0]  |0.0  |[-233.49577146414012,-239.1269179114926,-245.83356875543274] |[0.9964239872769697,0.0035716454847156843,4.3672383146859385E-6]|0.0       |
# |[1.53,3.5,6.0,1.6,3.4,5.25,1.5,3.7,5.0,1.44,3.6,6.5,1.45,3.75,6.0,1.5,3.6,5.5]  |0.0  |[-181.3388672300712,-184.34379362404817,-188.08330312315957] |[0.9517285075995514,0.04715091518897476,0.0011205772114738766]  |0.0       |
# |[1.25,4.5,10.0,1.25,5.0,9.0,1.25,4.5,9.0,1.2,5.0,11.0,1.22,5.0,9.0,1.22,5.0,9.5]|0.0  |[-257.167590665482,-263.9026771496352,-271.85537848904346]   |[0.9988125213717001,0.001187061126093357,4.1750220643252153E-7] |0.0       |
# +--------------------------------------------------------------------------------+-----+-------------------------------------------------------------+----------------------------------------------------------------+----------+
# only showing top 5 rows
#
#   - Evaluating model
# Accuracy:  46.63 %
