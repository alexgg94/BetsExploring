# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql.types import * 
from pyspark.sql.functions import isnan, when, count, col
#from pyspark.ml.regression import LabeledPoint
from pyspark.ml.classification import NaiveBayes
from pyspark.ml.classification import NaiveBayesModel
from pyspark.ml.linalg import Vector, SparseVector, DenseVector, Matrices
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from random import shuffle
import matplotlib.pyplot as plt

# %%
spark = SparkSession.builder.appName("BetsExploring").getOrCreate()
sc = spark.sparkContext
sc
# Out:
# <SparkContext master=local[*] appName=BetsExploring>

# %%
betsHouses = ['B365', 'BS', 'BW', 'GB', 'IW', 'LB', 'SB', 'SJ', 'VC', 'WH']
quotaTypes = ['H','D','A']

# %%
# Selecting fields included in dataframe to use as features

def calcBetsHousesCols(df, betsHouses):
    betsHousesCols = []
    betsHousesOk = []
    for betsHouse in betsHouses:
        col = betsHouse + 'H'
        if col in df.columns:
            betsHousesOk.append(betsHouse)
            betsHousesCols.append(betsHouse + 'H')
            betsHousesCols.append(betsHouse + 'D')
            betsHousesCols.append(betsHouse + 'A')

    print ("Potential bets houses:", betsHouses)
    print ("Bets houses selected :" , betsHousesOk)
    print ("Bets houses columns  :", betsHousesCols)
    
    return betsHousesCols

# %%
# Cleaning nulls in dataframe, mixing deletion of columns and rows
# Columns with less than 'percDropping' not null rows will be deleted
# Rows with nulls aftes deleting columns will be deleted

def cleanNulls(df, percDropping):
    print ("Cleaning nulls:")
    totalrows = df.count()
    notnullrows = df.dropna().count()
    dropCols = []
    print ("Total rows:", totalrows)
    print ("Not null rows: ", notnullrows)
    print ("Percentage for dropping column: ", percDropping, "%")

    print ("\nNot null rows before cleaning:")
    dfok = df
    for col in df.columns:

        percOk = round((df.select(col).dropna().count() / totalrows) * 100, 2)
        print (col, "\t", df.select(col).dropna().count(), "\t(", percOk, "%)")

        # Dropping columnss with a lot of nulls
        if percOk < percDropping:
            dropCols.append(col)
            dfok = dfok.drop(col)
    #        print ("\tColumn dropped")

    # Dropping row with nulls
    dfok = dfok.dropna()
    percOk = round((dfok.count() / totalrows) * 100 , 2)
    print ("\nDropped columns:", dropCols)
    print ("Not null rows after cleaning: " , dfok.count(), "\t(", percOk, "%)")
    print ("Final columns:", dfok.columns)
    
    return dfok

# %%
# Converting text result to numeric result
# H: Home wins -> 0
# D: Draw -> 1
# A: Away wins -> 2

def resultToNumeric(df):
    df = df.withColumn("Label", when(df['FTR']=='H',0)
                             .when(df['FTR']=='D',1)
                             .when(df['FTR']=='A',2).cast("double"))
    df.groupBy("Label").count().show()
                      
    return df

# %%
# Create Dataframe with label and features 

def createLabelAndFeatures(df, betsHousesCols):
    vectorAssembler = VectorAssembler(
        inputCols = betsHousesCols, 
        outputCol = 'features')

    vec_df = vectorAssembler.transform(df)

    vec_df = vec_df.withColumn("label", df["Label"])

    #vec_df = vec_df.select(['features', 'label'])
    vec_df.select(['features', 'label']).show(5, False)
    #vec_df.printSchema()
    
    return vec_df

# %%
# Defining, Training and Avaluating Naive Bayes Model

def calcNaiveBayesModel(df, betsHousesCols):
    
    # Converting result to numeric
    print ("\n  - Converting result to numeric")
    df = resultToNumeric(df)

    # Creating vector with label and features for training
    print ("\n  - Creating vector with label and features for training")
    vectrain = createLabelAndFeatures(df, betsHousesCols)

    # Training model
    print ("\n  - Training model")
    nb = NaiveBayes(smoothing=1.0, modelType="multinomial")
    model = nb.fit(vectrain)
    print("Pi   :", model.pi)
    print("Theta:", model.theta)

    # Calculating auto-prediction to avaluate model
    print ("\n  - Calculating auto-prediction to avaluate model")
    predict_train = model.transform(vectrain)
    predict_train.show(5, False)

    # Evaluating model
    print ("\n  - Evaluating model")
    nb_evaluator = MulticlassClassificationEvaluator(predictionCol="prediction",labelCol="label",metricName="accuracy")
    results = nb_evaluator.evaluate(predict_train)
    print ("Accuracy: ", round(results * 100, 2), "%")
    
    return model

# %%
# Calculating predictions with test dataset
def calcPrediction (model, df, betsHousesCols):
    
    # Converting result to numeric
    print ("\n  - Converting result to numeric")
    df = resultToNumeric(df)

    # Creating vector with label and features for training
    print ("  - Creating vector with label and features for training")
    vectest = createLabelAndFeatures(df, betsHousesCols)

    # Calculating prediction
    print ("  - Calculating prediction")
    predict = model.transform(vectest)
    print(predict.count())
    predict.show(5, False)

    # Evaluating test
    print ("  - Evaluating model")
    nb_evaluator = MulticlassClassificationEvaluator(predictionCol="prediction",labelCol="label",metricName="accuracy")
    results = nb_evaluator.evaluate(predict)
    print ("Accuracy: ", round(results * 100, 2), "%")
    
    return predict

# %%
# Calculating Naive Bayes Model and Prediction

def calcModelAndTest(df):
    
    # Cleaning nulls in columns and rows
    print ("\n* Cleaning nulls in columns and rows")
    dfok = cleanNulls(df, 80)

    # Calculating Bets Houses Cols
    print ("\n  - Calculating Bets Houses Cols")
    betsHousesCols =  calcBetsHousesCols(dfok, betsHouses)

    # Spliting training and testing datasets
    print ("\n* Spliting training and testing datasets")
    dftrain, dftest = dfok.randomSplit([0.8, 0.2], seed=1)
    print("  Train dataset:", dftrain.count(), "rows")
    print("  Test dataset: ", dftest.count(), "rows")

    # Defining, Training and Avaluating Naive Bayes Model
    print ("\n* Defining, Training and Avaluating Naive Bayes Model")
    model = calcNaiveBayesModel(dftrain, betsHousesCols)

    # Calculating predictions with test dataset
    print ("\n* Calculating predictions with test dataset")
    predict = calcPrediction(model, dftest, betsHousesCols)

    return model

# %%
url = "../Data/Processed/main_competitions_recent.csv"
# Open Dataset file
print ("* Opening dataset file")
dfrecent = spark.read.csv(path = url, header = True, inferSchema = True)
print ("Rows   :", dfrecent.count())
print ("Columns:", dfrecent.columns)
print ("First row:")
print(dfrecent.take(1))
dfrecent.printSchema()

modelRecent = calcModelAndTest(dfrecent)
# Out:
# * Opening dataset file
# Rows   : 11374
# Columns: ['Country', 'Competition', 'Season', 'Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'VCH', 'VCD', 'VCA', 'WHH', 'WHD', 'WHA', 'Divergence']
# First row:
# [Row(Country='Belgium', Competition='JupilerLeague', Season='2017-2018', Div='B1', Date=datetime.datetime(2017, 7, 28, 0, 0), HomeTeam='Antwerp', AwayTeam='Anderlecht', FTR='D', B365H=5.75, B365D=3.8, B365A=1.6, BWH=5.0, BWD=4.0, BWA=1.67, IWH=4.7, IWD=3.6, IWA=1.7, LBH=5.2, LBD=3.7, LBA=1.61, VCH=5.5, VCD=3.9, VCA=1.62, WHH=4.75, WHD=3.75, WHA=1.67, Divergence=11.65048543689322)]
# root
#  |-- Country: string (nullable = true)
#  |-- Competition: string (nullable = true)
#  |-- Season: string (nullable = true)
#  |-- Div: string (nullable = true)
#  |-- Date: timestamp (nullable = true)
#  |-- HomeTeam: string (nullable = true)
#  |-- AwayTeam: string (nullable = true)
#  |-- FTR: string (nullable = true)
#  |-- B365H: double (nullable = true)
#  |-- B365D: double (nullable = true)
#  |-- B365A: double (nullable = true)
#  |-- BWH: double (nullable = true)
#  |-- BWD: double (nullable = true)
#  |-- BWA: double (nullable = true)
#  |-- IWH: double (nullable = true)
#  |-- IWD: double (nullable = true)
#  |-- IWA: double (nullable = true)
#  |-- LBH: double (nullable = true)
#  |-- LBD: double (nullable = true)
#  |-- LBA: double (nullable = true)
#  |-- VCH: double (nullable = true)
#  |-- VCD: double (nullable = true)
#  |-- VCA: double (nullable = true)
#  |-- WHH: double (nullable = true)
#  |-- WHD: double (nullable = true)
#  |-- WHA: double (nullable = true)
#  |-- Divergence: double (nullable = true)
#
#
# * Cleaning nulls in columns and rows
# Cleaning nulls:
# Total rows: 11374
# Not null rows:  7668
# Percentage for dropping column:  80 %
#
# Not null rows before cleaning:
# Country 	 11374 	( 100.0 %)
# Competition 	 11374 	( 100.0 %)
# Season 	 11374 	( 100.0 %)
# Div 	 11374 	( 100.0 %)
# Date 	 11374 	( 100.0 %)
# HomeTeam 	 11374 	( 100.0 %)
# AwayTeam 	 11374 	( 100.0 %)
# FTR 	 11374 	( 100.0 %)
# B365H 	 11360 	( 99.88 %)
# B365D 	 11360 	( 99.88 %)
# B365A 	 11360 	( 99.88 %)
# BWH 	 11362 	( 99.89 %)
# BWD 	 11362 	( 99.89 %)
# BWA 	 11362 	( 99.89 %)
# IWH 	 11344 	( 99.74 %)
# IWD 	 11344 	( 99.74 %)
# IWA 	 11340 	( 99.7 %)
# LBH 	 7694 	( 67.65 %)
# LBD 	 7694 	( 67.65 %)
# LBA 	 7698 	( 67.68 %)
# VCH 	 11356 	( 99.84 %)
# VCD 	 11356 	( 99.84 %)
# VCA 	 11356 	( 99.84 %)
# WHH 	 11358 	( 99.86 %)
# WHD 	 11358 	( 99.86 %)
# WHA 	 11358 	( 99.86 %)
# Divergence 	 11374 	( 100.0 %)
#
# Dropped columns: ['LBH', 'LBD', 'LBA']
# Not null rows after cleaning:  11304 	( 99.38 %)
# Final columns: ['Country', 'Competition', 'Season', 'Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'VCH', 'VCD', 'VCA', 'WHH', 'WHD', 'WHA', 'Divergence']
#
#   - Calculating Bets Houses Cols
# Potential bets houses: ['B365', 'BS', 'BW', 'GB', 'IW', 'LB', 'SB', 'SJ', 'VC', 'WH']
# Bets houses selected : ['B365', 'BW', 'IW', 'VC', 'WH']
# Bets houses columns  : ['B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'VCH', 'VCD', 'VCA', 'WHH', 'WHD', 'WHA']
#
# * Spliting training and testing datasets
#   Train dataset: 8973 rows
#   Test dataset:  2331 rows
#
# * Defining, Training and Avaluating Naive Bayes Model
#
#   - Converting result to numeric
# +-----+-----+
# |Label|count|
# +-----+-----+
# |  0.0| 3934|
# |  1.0| 2378|
# |  2.0| 2661|
# +-----+-----+
#
#
#   - Creating vector with label and features for training
# +-------------------------------------------------------------------+-----+
# |features                                                           |label|
# +-------------------------------------------------------------------+-----+
# |[1.62,4.0,5.0,1.6,3.8,5.5,1.7,3.7,4.5,1.65,4.0,5.0,1.62,3.8,5.0]   |0.0  |
# |[1.7,3.6,5.0,1.7,3.6,5.0,1.7,3.7,4.5,1.75,3.8,4.4,1.75,3.6,4.33]   |0.0  |
# |[1.53,4.0,6.25,1.57,4.0,5.5,1.55,4.0,5.5,1.57,4.2,5.4,1.62,3.8,5.0]|2.0  |
# |[1.9,3.6,3.75,1.91,3.5,4.1,1.9,3.45,3.8,2.0,3.5,3.6,2.0,3.4,3.5]   |1.0  |
# |[7.0,4.0,1.5,5.75,4.1,1.57,5.5,4.0,1.55,5.75,4.1,1.55,6.0,3.8,1.53]|2.0  |
# +-------------------------------------------------------------------+-----+
# only showing top 5 rows
#
#
#   - Training model
# Pi   : [-0.824643466911,-1.32787411746,-1.21547662881]
# Theta: DenseMatrix([[-3.2531795 , -2.64402429, -2.36243739, -3.26665357, -2.66057714,
#               -2.39315345, -3.27782149, -2.69446288, -2.45040114, -3.24816115,
#               -2.62881041, -2.33001236, -3.26201643, -2.67184672, -2.41448805],
#              [-2.96478428, -2.6101748 , -2.54048622, -2.98352853, -2.62748511,
#               -2.56973434, -2.99983881, -2.6517907 , -2.61021806, -2.9586107 ,
#               -2.60021446, -2.53892467, -2.98065205, -2.63281479, -2.58926739],
#              [-2.68547974, -2.60777643, -2.78171451, -2.713572  , -2.62379914,
#               -2.8032836 , -2.75257048, -2.65026367, -2.8330401 , -2.67434483,
#               -2.59566017, -2.78117667, -2.71609587, -2.62931028, -2.81776784]])
#
#   - Calculating auto-prediction to avaluate model
# +-------+-------------+---------+---+-------------------+-----------+----------+---+-----+-----+-----+----+---+----+----+----+----+----+---+----+----+---+----+------------------+-----+-------------------------------------------------------------------+-------------------------------------------------------------+---------------------------------------------------------------+----------+
# |Country|Competition  |Season   |Div|Date               |HomeTeam   |AwayTeam  |FTR|B365H|B365D|B365A|BWH |BWD|BWA |IWH |IWD |IWA |VCH |VCD|VCA |WHH |WHD|WHA |Divergence        |label|features                                                           |rawPrediction                                                |probability                                                    |prediction|
# +-------+-------------+---------+---+-------------------+-----------+----------+---+-----+-----+-----+----+---+----+----+----+----+----+---+----+----+---+----+------------------+-----+-------------------------------------------------------------------+-------------------------------------------------------------+---------------------------------------------------------------+----------+
# |Belgium|JupilerLeague|2017-2018|B1 |2017-01-10 00:00:00|Anderlecht |Standard  |H  |1.62 |4.0  |5.0  |1.6 |3.8|5.5 |1.7 |3.7 |4.5 |1.65|4.0|5.0 |1.62|3.8|5.0 |10.924369747899165|0.0  |[1.62,4.0,5.0,1.6,3.8,5.5,1.7,3.7,4.5,1.65,4.0,5.0,1.62,3.8,5.0]   |[-138.58556920219803,-140.57979402076523,-144.05135620671567]|[0.8769251804381182,0.11936629290156024,0.0037085266603216634] |0.0       |
# |Belgium|JupilerLeague|2017-2018|B1 |2017-01-10 00:00:00|Club Brugge|Gent      |H  |1.7  |3.6  |5.0  |1.7 |3.6|5.0 |1.7 |3.7 |4.5 |1.75|3.8|4.4 |1.75|3.6|4.33|9.170305676855905 |0.0  |[1.7,3.6,5.0,1.7,3.6,5.0,1.7,3.7,4.5,1.75,3.8,4.4,1.75,3.6,4.33]   |[-133.05921947323003,-134.63947154002267,-137.58696199164368]|[0.8218762239795288,0.16924336993589081,0.008880406084580484]  |0.0       |
# |Belgium|JupilerLeague|2017-2018|B1 |2017-01-10 00:00:00|Waregem    |Lokeren   |A  |1.53 |4.0  |6.25 |1.57|4.0|5.5 |1.55|4.0 |5.5 |1.57|4.2|5.4 |1.62|3.8|5.0 |14.155251141552494|2.0  |[1.53,4.0,6.25,1.57,4.0,5.5,1.55,4.0,5.5,1.57,4.2,5.4,1.62,3.8,5.0]|[-145.64492652064752,-148.1792657317731,-152.36304757976566] |[0.9254778239647202,0.07340345163102341,0.0011187244042562482] |0.0       |
# |Belgium|JupilerLeague|2017-2018|B1 |2017-01-12 00:00:00|Charleroi  |Oostende  |D  |1.9  |3.6  |3.75 |1.91|3.5|4.1 |1.9 |3.45|3.8 |2.0 |3.5|3.6 |2.0 |3.4|3.5 |10.561797752808966|1.0  |[1.9,3.6,3.75,1.91,3.5,4.1,1.9,3.45,3.8,2.0,3.5,3.6,2.0,3.4,3.5]   |[-123.72607481318903,-124.21567636206096,-125.81561130677355]|[0.5758328625130401,0.35291099998937064,0.07125613749758919]   |0.0       |
# |Belgium|JupilerLeague|2017-2018|B1 |2017-02-12 00:00:00|Lokeren    |Anderlecht|A  |7.0  |4.0  |1.5  |5.75|4.1|1.57|5.5 |4.0 |1.55|5.75|4.1|1.55|6.0 |3.8|1.53|18.309859154929576|2.0  |[7.0,4.0,1.5,5.75,4.1,1.57,5.5,4.0,1.55,5.75,4.1,1.55,6.0,3.8,1.53]|[-170.25537121328023,-162.90577938669531,-156.44033989543217]|[9.989237234588793E-7,0.0015538872450966545,0.9984451138311798]|2.0       |
# +-------+-------------+---------+---+-------------------+-----------+----------+---+-----+-----+-----+----+---+----+----+----+----+----+---+----+----+---+----+------------------+-----+-------------------------------------------------------------------+-------------------------------------------------------------+---------------------------------------------------------------+----------+
# only showing top 5 rows
#
#
#   - Evaluating model
# Accuracy:  48.16 %
#
# * Calculating predictions with test dataset
#
#   - Converting result to numeric
# +-----+-----+
# |Label|count|
# +-----+-----+
# |  0.0| 1062|
# |  1.0|  589|
# |  2.0|  680|
# +-----+-----+
#
#   - Creating vector with label and features for training
# +--------------------------------------------------------------------+-----+
# |features                                                            |label|
# +--------------------------------------------------------------------+-----+
# |[2.6,3.5,2.54,2.55,3.5,2.7,2.85,3.4,2.3,2.55,3.5,2.63,2.5,3.4,2.6]  |0.0  |
# |[1.53,3.79,6.5,1.57,4.1,6.0,1.55,4.0,5.5,1.53,4.1,6.0,1.53,3.8,6.0] |1.0  |
# |[3.3,3.25,2.2,3.2,3.25,2.35,2.9,3.3,2.3,3.13,3.25,2.3,3.2,3.2,2.2]  |2.0  |
# |[1.75,3.75,4.33,1.83,3.7,4.25,1.85,3.5,3.9,1.87,3.6,4.0,1.8,3.5,4.2]|0.0  |
# |[1.4,4.5,8.0,1.42,4.6,7.75,1.4,4.4,7.3,1.4,4.8,7.5,1.4,4.5,7.0]     |0.0  |
# +--------------------------------------------------------------------+-----+
# only showing top 5 rows
#
#   - Calculating prediction
# 2331
# +-------+-------------+---------+---+-------------------+----------+----------------+---+-----+-----+-----+----+----+----+----+---+---+----+----+----+----+---+---+-----------------+-----+--------------------------------------------------------------------+-------------------------------------------------------------+---------------------------------------------------------------+----------+
# |Country|Competition  |Season   |Div|Date               |HomeTeam  |AwayTeam        |FTR|B365H|B365D|B365A|BWH |BWD |BWA |IWH |IWD|IWA|VCH |VCD |VCA |WHH |WHD|WHA|Divergence       |label|features                                                            |rawPrediction                                                |probability                                                    |prediction|
# +-------+-------------+---------+---+-------------------+----------+----------------+---+-----+-----+-----+----+----+----+----+---+---+----+----+----+----+---+---+-----------------+-----+--------------------------------------------------------------------+-------------------------------------------------------------+---------------------------------------------------------------+----------+
# |Belgium|JupilerLeague|2017-2018|B1 |2017-02-12 00:00:00|Kortrijk  |Waasland-Beveren|H  |2.6  |3.5  |2.54 |2.55|3.5 |2.7 |2.85|3.4|2.3|2.55|3.5 |2.63|2.5 |3.4|2.6|9.967845659163977|0.0  |[2.6,3.5,2.54,2.55,3.5,2.7,2.85,3.4,2.3,2.55,3.5,2.63,2.5,3.4,2.6]  |[-119.90854343337756,-118.39424430490911,-117.7089577548774] |[0.06864591746757903,0.31208038227510093,0.61927370025732]     |2.0       |
# |Belgium|JupilerLeague|2017-2018|B1 |2017-03-12 00:00:00|Standard  |Antwerp         |D  |1.53 |3.79 |6.5  |1.57|4.1 |6.0 |1.55|4.0|5.5|1.53|4.1 |6.0 |1.53|3.8|6.0|8.333333333333337|1.0  |[1.53,3.79,6.5,1.57,4.1,6.0,1.55,4.0,5.5,1.53,4.1,6.0,1.53,3.8,6.0] |[-150.269031702116,-153.27986388921582,-158.0503502714462]   |[0.9526820568137405,0.046920235239363436,3.977079468959337E-4] |0.0       |
# |Belgium|JupilerLeague|2017-2018|B1 |2017-05-08 00:00:00|Mouscron  |Charleroi       |A  |3.3  |3.25 |2.2  |3.2 |3.25|2.35|2.9 |3.3|2.3|3.13|3.25|2.3 |3.2 |3.2|2.2|7.594264471587886|2.0  |[3.3,3.25,2.2,3.2,3.25,2.35,2.9,3.3,2.3,3.13,3.25,2.3,3.2,3.2,2.2]  |[-122.47762964443216,-119.97339437564986,-118.2231060276952] |[0.011953506561771942,0.14624158415945754,0.8418049092787705]  |2.0       |
# |Belgium|JupilerLeague|2017-2018|B1 |2017-05-08 00:00:00|Waregem   |St Truiden      |H  |1.75 |3.75 |4.33 |1.83|3.7 |4.25|1.85|3.5|3.9|1.87|3.6 |4.0 |1.8 |3.5|4.2|5.695687550854345|0.0  |[1.75,3.75,4.33,1.83,3.7,4.25,1.85,3.5,3.9,1.87,3.6,4.0,1.8,3.5,4.2]|[-127.92809161296766,-128.92247140169374,-131.14022669617728]|[0.7091075260790759,0.26233633059888606,0.02855614332203803]   |0.0       |
# |Belgium|JupilerLeague|2017-2018|B1 |2017-06-08 00:00:00|Anderlecht|Oostende        |H  |1.4  |4.5  |8.0  |1.42|4.6 |7.75|1.4 |4.4|7.3|1.4 |4.8 |7.5 |1.4 |4.5|7.0|6.770255271920078|0.0  |[1.4,4.5,8.0,1.42,4.6,7.75,1.4,4.4,7.3,1.4,4.8,7.5,1.4,4.5,7.0]     |[-174.06581823207821,-178.51944742050904,-185.22888794778058]|[0.9884837211210639,0.011502253650521944,1.4025228414161577E-5]|0.0       |
# +-------+-------------+---------+---+-------------------+----------+----------------+---+-----+-----+-----+----+----+----+----+---+---+----+----+----+----+---+---+-----------------+-----+--------------------------------------------------------------------+-------------------------------------------------------------+---------------------------------------------------------------+----------+
# only showing top 5 rows
#
#   - Evaluating model
# Accuracy:  48.05 %

# %%
url = "../Data/Processed/main_competitions.csv"
# Open Dataset file
print ("* Opening dataset file")
df = spark.read.csv(path = url, header = True, inferSchema = True)
print ("Rows   :", df.count())
print ("Columns:", df.columns)
print ("First row:")
print(df.take(1))
df.printSchema()

model = calcModelAndTest(df)
# Out:
# * Opening dataset file
# Rows   : 106586
# Columns: ['Country', 'Competition', 'Season', 'Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTR', 'B365H', 'B365D', 'B365A', 'BSH', 'BSD', 'BSA', 'BWH', 'BWD', 'BWA', 'GBH', 'GBD', 'GBA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'SBH', 'SBD', 'SBA', 'SJH', 'SJD', 'SJA', 'VCH', 'VCD', 'VCA', 'WHH', 'WHD', 'WHA', 'Divergence']
# First row:
# [Row(Country='Belgium', Competition='JupilerLeague', Season='2003-2004', Div='B1', Date=datetime.datetime(2003, 8, 8, 0, 0), HomeTeam='Club Brugge', AwayTeam='Genk', FTR='H', B365H=1.4, B365D=3.75, B365A=7.0, BSH=None, BSD=None, BSA=None, BWH=None, BWD=None, BWA=None, GBH=1.4, GBD=3.8, GBA=6.85, IWH=1.45, IWD=3.8, IWA=5.4, LBH=None, LBD=None, LBA=None, SBH=1.44, SBD=3.75, SBA=6.5, SJH=None, SJD=None, SJA=None, VCH=None, VCD=None, VCA=None, WHH=None, WHD=None, WHA=None, Divergence=16.11650485436893)]
# root
#  |-- Country: string (nullable = true)
#  |-- Competition: string (nullable = true)
#  |-- Season: string (nullable = true)
#  |-- Div: string (nullable = true)
#  |-- Date: timestamp (nullable = true)
#  |-- HomeTeam: string (nullable = true)
#  |-- AwayTeam: string (nullable = true)
#  |-- FTR: string (nullable = true)
#  |-- B365H: double (nullable = true)
#  |-- B365D: double (nullable = true)
#  |-- B365A: double (nullable = true)
#  |-- BSH: double (nullable = true)
#  |-- BSD: double (nullable = true)
#  |-- BSA: double (nullable = true)
#  |-- BWH: double (nullable = true)
#  |-- BWD: double (nullable = true)
#  |-- BWA: double (nullable = true)
#  |-- GBH: double (nullable = true)
#  |-- GBD: double (nullable = true)
#  |-- GBA: double (nullable = true)
#  |-- IWH: double (nullable = true)
#  |-- IWD: double (nullable = true)
#  |-- IWA: double (nullable = true)
#  |-- LBH: double (nullable = true)
#  |-- LBD: double (nullable = true)
#  |-- LBA: double (nullable = true)
#  |-- SBH: double (nullable = true)
#  |-- SBD: double (nullable = true)
#  |-- SBA: double (nullable = true)
#  |-- SJH: double (nullable = true)
#  |-- SJD: double (nullable = true)
#  |-- SJA: double (nullable = true)
#  |-- VCH: double (nullable = true)
#  |-- VCD: double (nullable = true)
#  |-- VCA: double (nullable = true)
#  |-- WHH: double (nullable = true)
#  |-- WHD: double (nullable = true)
#  |-- WHA: double (nullable = true)
#  |-- Divergence: double (nullable = true)
#
#
# * Cleaning nulls in columns and rows
# Cleaning nulls:
# Total rows: 106586
# Not null rows:  34323
# Percentage for dropping column:  80 %
#
# Not null rows before cleaning:
# Country 	 106586 	( 100.0 %)
# Competition 	 106586 	( 100.0 %)
# Season 	 106586 	( 100.0 %)
# Div 	 106586 	( 100.0 %)
# Date 	 106583 	( 100.0 %)
# HomeTeam 	 106586 	( 100.0 %)
# AwayTeam 	 106586 	( 100.0 %)
# FTR 	 106586 	( 100.0 %)
# B365H 	 106322 	( 99.75 %)
# B365D 	 106322 	( 99.75 %)
# B365A 	 106322 	( 99.75 %)
# BSH 	 44825 	( 42.06 %)
# BSD 	 44826 	( 42.06 %)
# BSA 	 44825 	( 42.06 %)
# BWH 	 104027 	( 97.6 %)
# BWD 	 104027 	( 97.6 %)
# BWA 	 104027 	( 97.6 %)
# GBH 	 64214 	( 60.25 %)
# GBD 	 64214 	( 60.25 %)
# GBA 	 64214 	( 60.25 %)
# IWH 	 105208 	( 98.71 %)
# IWD 	 105208 	( 98.71 %)
# IWA 	 105204 	( 98.7 %)
# LBH 	 100939 	( 94.7 %)
# LBD 	 100939 	( 94.7 %)
# LBA 	 100943 	( 94.71 %)
# SBH 	 56297 	( 52.82 %)
# SBD 	 56298 	( 52.82 %)
# SBA 	 56298 	( 52.82 %)
# SJH 	 68687 	( 64.44 %)
# SJD 	 68687 	( 64.44 %)
# SJA 	 68687 	( 64.44 %)
# VCH 	 101884 	( 95.59 %)
# VCD 	 101883 	( 95.59 %)
# VCA 	 101884 	( 95.59 %)
# WHH 	 104203 	( 97.76 %)
# WHD 	 104203 	( 97.76 %)
# WHA 	 104203 	( 97.76 %)
# Divergence 	 106583 	( 100.0 %)
#
# Dropped columns: ['BSH', 'BSD', 'BSA', 'GBH', 'GBD', 'GBA', 'SBH', 'SBD', 'SBA', 'SJH', 'SJD', 'SJA']
# Not null rows after cleaning:  94380 	( 88.55 %)
# Final columns: ['Country', 'Competition', 'Season', 'Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'VCH', 'VCD', 'VCA', 'WHH', 'WHD', 'WHA', 'Divergence']
#
#   - Calculating Bets Houses Cols
# Potential bets houses: ['B365', 'BS', 'BW', 'GB', 'IW', 'LB', 'SB', 'SJ', 'VC', 'WH']
# Bets houses selected : ['B365', 'BW', 'IW', 'LB', 'VC', 'WH']
# Bets houses columns  : ['B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'VCH', 'VCD', 'VCA', 'WHH', 'WHD', 'WHA']
#
# * Spliting training and testing datasets
#   Train dataset: 75377 rows
#   Test dataset:  19003 rows
#
# * Defining, Training and Avaluating Naive Bayes Model
#
#   - Converting result to numeric
# +-----+-----+
# |Label|count|
# +-----+-----+
# |  0.0|33860|
# |  1.0|20078|
# |  2.0|21439|
# +-----+-----+
#
#
#   - Creating vector with label and features for training
# +---------------------------------------------------------------------------------+-----+
# |features                                                                         |label|
# +---------------------------------------------------------------------------------+-----+
# |[1.2,5.5,10.0,1.2,5.5,10.5,1.15,6.0,12.0,1.2,5.0,11.0,1.15,6.0,11.0,1.2,5.0,11.0]|0.0  |
# |[1.61,3.4,5.0,1.6,3.4,5.25,1.6,3.4,4.6,1.61,3.25,5.0,1.65,3.4,4.35,1.6,3.5,4.6]  |1.0  |
# |[2.1,3.25,3.0,2.15,3.1,3.1,2.2,3.1,2.8,2.0,3.2,3.2,2.1,3.4,2.9,2.1,3.2,3.0]      |2.0  |
# |[1.4,4.0,6.5,1.4,4.0,6.75,1.4,3.9,6.0,1.4,3.75,7.0,1.4,4.0,6.5,1.4,4.0,6.2]      |0.0  |
# |[1.72,3.4,4.2,1.85,3.2,3.85,1.8,3.1,3.8,1.72,3.4,4.0,1.8,3.25,4.0,1.75,3.35,3.9] |0.0  |
# +---------------------------------------------------------------------------------+-----+
# only showing top 5 rows
#
#
#   - Training model
# Pi   : [-0.800278078197,-1.32286749505,-1.25728365164]
# Theta: DenseMatrix([[-3.39246159, -2.81817481, -2.54213696, -3.41090376, -2.8463603 ,
#               -2.5966142 , -3.42179684, -2.88550444, -2.66454933, -3.41471091,
#               -2.85318709, -2.59321422, -3.39144024, -2.81288603, -2.52569054,
#               -3.40307987, -2.8590239 , -2.5950427 ],
#              [-3.14564311, -2.7917521 , -2.70420681, -3.17033836, -2.8180451 ,
#               -2.74461842, -3.19201583, -2.84678855, -2.79674698, -3.17714488,
#               -2.81909671, -2.74821945, -3.14444532, -2.78992816, -2.70105703,
#               -3.16395477, -2.82553539, -2.74857474],
#              [-2.93368308, -2.78169852, -2.88128855, -2.96944308, -2.8092191 ,
#               -2.9130017 , -3.00782101, -2.84066799, -2.95257637, -2.97615274,
#               -2.80895585, -2.91674787, -2.92668238, -2.77902249, -2.8794673 ,
#               -2.96210436, -2.81627884, -2.91555525]])
#
#   - Calculating auto-prediction to avaluate model
# +-------+-------------+---------+---+-------------------+-----------+-----------+---+-----+-----+-----+----+---+----+----+---+----+----+----+----+----+----+----+----+----+----+------------------+-----+---------------------------------------------------------------------------------+-------------------------------------------------------------+----------------------------------------------------------------+----------+
# |Country|Competition  |Season   |Div|Date               |HomeTeam   |AwayTeam   |FTR|B365H|B365D|B365A|BWH |BWD|BWA |IWH |IWD|IWA |LBH |LBD |LBA |VCH |VCD |VCA |WHH |WHD |WHA |Divergence        |label|features                                                                         |rawPrediction                                                |probability                                                     |prediction|
# +-------+-------------+---------+---+-------------------+-----------+-----------+---+-----+-----+-----+----+---+----+----+---+----+----+----+----+----+----+----+----+----+----+------------------+-----+---------------------------------------------------------------------------------+-------------------------------------------------------------+----------------------------------------------------------------+----------+
# |Belgium|JupilerLeague|2005-2006|B1 |2005-01-10 00:00:00|Anderlecht |St Truiden |H  |1.2  |5.5  |10.0 |1.2 |5.5|10.5|1.15|6.0|12.0|1.2 |5.0 |11.0|1.15|6.0 |11.0|1.2 |5.0 |11.0|18.181818181818187|0.0  |[1.2,5.5,10.0,1.2,5.5,10.5,1.15,6.0,12.0,1.2,5.0,11.0,1.15,6.0,11.0,1.2,5.0,11.0]|[-288.40106163360883,-296.2935292491309,-305.5457800914103]  |[0.9996265570230792,3.7340716882995536E-4,3.5808090748019164E-8]|0.0       |
# |Belgium|JupilerLeague|2005-2006|B1 |2005-01-10 00:00:00|Gent       |Lierse     |D  |1.61 |3.4  |5.0  |1.6 |3.4|5.25|1.6 |3.4|4.6 |1.61|3.25|5.0 |1.65|3.4 |4.35|1.6 |3.5 |4.6 |9.628770301624122 |1.0  |[1.61,3.4,5.0,1.6,3.4,5.25,1.6,3.4,4.6,1.61,3.25,5.0,1.65,3.4,4.35,1.6,3.5,4.6]  |[-166.13619722690981,-168.15202675430322,-170.8088139977042] |[0.8752293724974382,0.11658917893686617,0.008181448565695885]   |0.0       |
# |Belgium|JupilerLeague|2005-2006|B1 |2005-01-10 00:00:00|Louvieroise|FC Brussels|A  |2.1  |3.25 |3.0  |2.15|3.1|3.1 |2.2 |3.1|2.8 |2.0 |3.2 |3.2 |2.1 |3.4 |2.9 |2.1 |3.2 |3.0 |6.9423929098966   |2.0  |[2.1,3.25,3.0,2.15,3.1,3.1,2.2,3.1,2.8,2.0,3.2,3.2,2.1,3.4,2.9,2.1,3.2,3.0]      |[-145.1990632669009,-144.87698831129472,-145.11498111473873] |[0.2883750432667621,0.39795415974720083,0.313670796986037]      |1.0       |
# |Belgium|JupilerLeague|2005-2006|B1 |2005-01-10 00:00:00|Standard   |Lokeren    |H  |1.4  |4.0  |6.5  |1.4 |4.0|6.75|1.4 |3.9|6.0 |1.4 |3.75|7.0 |1.4 |4.0 |6.5 |1.4 |4.0 |6.2 |20.10008340283569 |0.0  |[1.4,4.0,6.5,1.4,4.0,6.75,1.4,3.9,6.0,1.4,3.75,7.0,1.4,4.0,6.5,1.4,4.0,6.2]      |[-197.40421246818823,-201.2085284180546,-205.81740071808346] |[0.9779986011978097,0.021784360191132893,2.170386110573851E-4]  |0.0       |
# |Belgium|JupilerLeague|2005-2006|B1 |2005-01-10 00:00:00|Westerlo   |Beveren    |H  |1.72 |3.4  |4.2  |1.85|3.2|3.85|1.8 |3.1|3.8 |1.72|3.4 |4.0 |1.8 |3.25|4.0 |1.75|3.35|3.9 |6.060606060606055 |0.0  |[1.72,3.4,4.2,1.85,3.2,3.85,1.8,3.1,3.8,1.72,3.4,4.0,1.8,3.25,4.0,1.75,3.35,3.9] |[-154.48917300222874,-155.52686004118306,-157.14339846763752]|[0.7019383855950464,0.24867792651747417,0.04938368788747944]    |0.0       |
# +-------+-------------+---------+---+-------------------+-----------+-----------+---+-----+-----+-----+----+---+----+----+---+----+----+----+----+----+----+----+----+----+----+------------------+-----+---------------------------------------------------------------------------------+-------------------------------------------------------------+----------------------------------------------------------------+----------+
# only showing top 5 rows
#
#
#   - Evaluating model
# Accuracy:  47.19 %
#
# * Calculating predictions with test dataset
#
#   - Converting result to numeric
# +-----+-----+
# |Label|count|
# +-----+-----+
# |  0.0| 8513|
# |  1.0| 5012|
# |  2.0| 5478|
# +-----+-----+
#
#   - Creating vector with label and features for training
# +--------------------------------------------------------------------------------+-----+
# |features                                                                        |label|
# +--------------------------------------------------------------------------------+-----+
# |[1.66,3.4,4.5,1.8,3.2,4.05,1.75,3.2,4.0,1.72,3.4,4.0,1.7,3.6,4.0,1.6,3.5,4.6]   |0.0  |
# |[2.5,3.2,2.5,2.5,3.2,2.5,2.6,3.0,2.4,2.38,3.2,2.6,2.35,3.25,2.5,2.45,3.25,2.45] |1.0  |
# |[1.3,4.5,8.5,1.3,4.5,8.5,1.27,4.3,8.5,1.29,4.33,9.0,1.28,4.5,8.0,1.28,4.5,8.0]  |0.0  |
# |[1.53,3.5,6.0,1.6,3.4,5.25,1.5,3.7,5.0,1.44,3.6,6.5,1.45,3.75,6.0,1.5,3.6,5.5]  |0.0  |
# |[1.25,4.5,10.0,1.25,5.0,9.0,1.25,4.5,9.0,1.2,5.0,11.0,1.22,5.0,9.0,1.22,5.0,9.5]|0.0  |
# +--------------------------------------------------------------------------------+-----+
# only showing top 5 rows
#
#   - Calculating prediction
# 19003
# +-------+-------------+---------+---+-------------------+----------+-----------+---+-----+-----+-----+----+---+----+----+---+---+----+----+----+----+----+---+----+----+----+------------------+-----+--------------------------------------------------------------------------------+-------------------------------------------------------------+---------------------------------------------------------------+----------+
# |Country|Competition  |Season   |Div|Date               |HomeTeam  |AwayTeam   |FTR|B365H|B365D|B365A|BWH |BWD|BWA |IWH |IWD|IWA|LBH |LBD |LBA |VCH |VCD |VCA|WHH |WHD |WHA |Divergence        |label|features                                                                        |rawPrediction                                                |probability                                                    |prediction|
# +-------+-------------+---------+---+-------------------+----------+-----------+---+-----+-----+-----+----+---+----+----+---+---+----+----+----+----+----+---+----+----+----+------------------+-----+--------------------------------------------------------------------------------+-------------------------------------------------------------+---------------------------------------------------------------+----------+
# |Belgium|JupilerLeague|2005-2006|B1 |2005-01-10 00:00:00|Waregem   |Roeselare  |H  |1.66 |3.4  |4.5  |1.8 |3.2|4.05|1.75|3.2|4.0|1.72|3.4 |4.0 |1.7 |3.6 |4.0|1.6 |3.5 |4.6 |7.953063885267264 |0.0  |[1.66,3.4,4.5,1.8,3.2,4.05,1.75,3.2,4.0,1.72,3.4,4.0,1.7,3.6,4.0,1.6,3.5,4.6]   |[-158.4277020948636,-159.75948745657394,-161.68908773758247] |[0.7678482070081154,0.2027161459655326,0.029435647026351954]   |0.0       |
# |Belgium|JupilerLeague|2005-2006|B1 |2005-03-12 00:00:00|Lierse    |FC Brussels|D  |2.5  |3.2  |2.5  |2.5 |3.2|2.5 |2.6 |3.0|2.4|2.38|3.2 |2.6 |2.35|3.25|2.5|2.45|3.25|2.45|5.923344947735187 |1.0  |[2.5,3.2,2.5,2.5,3.2,2.5,2.6,3.0,2.4,2.38,3.2,2.6,2.35,3.25,2.5,2.45,3.25,2.45] |[-144.14297128409282,-142.8441626239431,-142.13709687443247] |[0.08266158345232223,0.3029487427203836,0.6143896738272943]    |2.0       |
# |Belgium|JupilerLeague|2005-2006|B1 |2005-05-11 00:00:00|Anderlecht|Charleroi  |H  |1.3  |4.5  |8.5  |1.3 |4.5|8.5 |1.27|4.3|8.5|1.29|4.33|9.0 |1.28|4.5 |8.0|1.28|4.5 |8.0 |25.31645569620251 |0.0  |[1.3,4.5,8.5,1.3,4.5,8.5,1.27,4.3,8.5,1.29,4.33,9.0,1.28,4.5,8.0,1.28,4.5,8.0]  |[-233.50111774080858,-239.14071844402224,-245.8030783565668] |[0.9964537901910373,0.0035416830898035365,4.526719159228662E-6]|0.0       |
# |Belgium|JupilerLeague|2005-2006|B1 |2005-05-11 00:00:00|Genk      |Roeselare  |H  |1.53 |3.5  |6.0  |1.6 |3.4|5.25|1.5 |3.7|5.0|1.44|3.6 |6.5 |1.45|3.75|6.0|1.5 |3.6 |5.5 |19.658119658119656|0.0  |[1.53,3.5,6.0,1.6,3.4,5.25,1.5,3.7,5.0,1.44,3.6,6.5,1.45,3.75,6.0,1.5,3.6,5.5]  |[-181.34072636607183,-184.35039471747467,-188.06619659105837]|[0.9519204176480103,0.04693731954736203,0.0011422628046277707] |0.0       |
# |Belgium|JupilerLeague|2005-2006|B1 |2005-06-08 00:00:00|Anderlecht|Louvieroise|H  |1.25 |4.5  |10.0 |1.25|5.0|9.0 |1.25|4.5|9.0|1.2 |5.0 |11.0|1.22|5.0 |9.0|1.22|5.0 |9.5 |19.33701657458564 |0.0  |[1.25,4.5,10.0,1.25,5.0,9.0,1.25,4.5,9.0,1.2,5.0,11.0,1.22,5.0,9.0,1.22,5.0,9.5]|[-257.17385993588965,-263.91888980041097,-271.8199966823732] |[0.9988242347381445,0.0011753299979032552,4.352639520746469E-7]|0.0       |
# +-------+-------------+---------+---+-------------------+----------+-----------+---+-----+-----+-----+----+---+----+----+---+---+----+----+----+----+----+---+----+----+----+------------------+-----+--------------------------------------------------------------------------------+-------------------------------------------------------------+---------------------------------------------------------------+----------+
# only showing top 5 rows
#
#   - Evaluating model
# Accuracy:  47.44 %

# %% [markdown]
# **Naive Bayes model with DataFrames**
#
# Model accuracy: 48.16 %
#
# Prediction accuracy: 47.44 %

# %%
# Reorder and reformat columns of resulting dataset

def reformatResult(match):
    newRow = []
    for col in match:
        newRow.append(col)
    
    newRow.append(int(newRow[4][0]*10000)/100)
    newRow.append(int(newRow[4][1]*10000)/100)
    newRow.append(int(newRow[4][2]*10000)/100)
    del newRow[4]
    
    return newRow

# %%
# Define the schema of the resulting dataset

def defineSchema():
    fields = []
    fields.append(StructField('Competition',StringType(), True))
    fields.append(StructField('HomeTeam',StringType(), True))
    fields.append(StructField('AwayTeam',StringType(), True))
    fields.append(StructField('Prediction',DoubleType(), True))
    fields.append(StructField('Label',DoubleType(), True))
    fields.append(StructField('HomeProb',DoubleType(), True))
    fields.append(StructField('DrawProb',DoubleType(), True))
    fields.append(StructField('AwayProb',DoubleType(), True))
    schema = StructType(fields)
    
    return schema

# %%
# calculate prediction of the week matches
# parameters: df: Dataframe with all the dataset
#   dataIni: Initial date of the week
#   dataFin: Final data of the week
def calcWeekPrediction(model, df, country, dateIni, dateFin):
    print ("WEEK PREDICTION")
    print ("---------------")
    print ("Country:", country, ", Initial date:", dateIni, ", Final Date:", dateFin)
    
    # Select desired data
    dfWeek = df.filter(df["Country"]==country).filter(df["Date"]>=dateIni).filter(df["Date"]<=dateFin)
    print ('Matches:', dfWeek.count())
    dfWeek.select("Competition","HomeTeam", "AwayTeam", "FTR").show()
    
    # Converting result to numeric
    print ("\n  - Converting result to numeric")
    dfWeek = resultToNumeric(dfWeek)
    
    # Cleaning nulls in columns and rows
    print ("\n* Cleaning nulls in columns and rows")
    dfok = cleanNulls(df, 80)
    
    # Calculating Bets Houses Cols
    print ("\n  - Calculating Bets Houses Cols")
    betsHousesCols =  calcBetsHousesCols(dfok, betsHouses)
    
    # Creating vector with label and features for prediction
    print ("\n  - Creating vector with label and features for training")
    vecWeek = createLabelAndFeatures(dfWeek, betsHousesCols)
    
    # Calculating prediction
    print ("\n  - Calculating prediction")
    predict = model.transform(vecWeek)
    print("Rows:", predict.count())
    predict.show(5, False)
    
    # Reordering and reformating columns of resulting dataset
    print ("\n - Reformating columns")
    result = predict.select("Competition","HomeTeam","AwayTeam","prediction","probability","label")
    rddnew = result.rdd.map(lambda match: (reformatResult(match)))
    schema = defineSchema()
    dfnew = spark.createDataFrame(rddnew, schema)
    dfnew.show()

    return dfnew

# %%
print (modelRecent)

prediction = calcWeekPrediction(modelRecent, dfrecent, "Spain", "2018-11-01", "2018-11-07")
# Out:
# NaiveBayes_409b81a409097b245011
# WEEK PREDICTION
# ---------------
# Country: Spain , Initial date: 2018-11-01 , Final Date: 2018-11-07
# Matches: 21
# +-----------+-------------+----------+---+
# |Competition|     HomeTeam|  AwayTeam|FTR|
# +-----------+-------------+----------+---+
# |    Primera|    Barcelona|    Getafe|  D|
# |    Primera|        Celta|   Espanol|  D|
# |    Primera|      Sevilla|    Girona|  H|
# |    Primera|     Valencia|   Levante|  H|
# |    Primera|   Ath Bilbao|   Leganes|  H|
# |    Primera|   Ath Madrid|     Celta|  H|
# |    Primera|      Espanol|  Sociedad|  H|
# |    Primera|   Las Palmas|Villarreal|  A|
# |    Segunda|     Albacete| Gimnastic|  A|
# |    Segunda|       Huesca|   Leonesa|  H|
# |    Segunda|Reus Deportiu|     Lorca|  H|
# |    Segunda|     Tenerife|   Cordoba|  H|
# |    Segunda|    Vallecano| Sevilla B|  H|
# |    Segunda|     Zaragoza|      Lugo|  H|
# |    Segunda|     Albacete|   Osasuna|  D|
# |    Segunda|  Barcelona B|  Numancia|  D|
# |    Segunda|      Cordoba|      Lugo|  H|
# |    Segunda|Reus Deportiu|    Huesca|  D|
# |    Segunda|     Sp Gijon|   Leonesa|  H|
# |    Segunda|     Zaragoza|     Lorca|  H|
# +-----------+-------------+----------+---+
# only showing top 20 rows
#
#
#   - Converting result to numeric
# +-----+-----+
# |Label|count|
# +-----+-----+
# |  0.0|   14|
# |  1.0|    5|
# |  2.0|    2|
# +-----+-----+
#
#
# * Cleaning nulls in columns and rows
# Cleaning nulls:
# Total rows: 11374
# Not null rows:  7668
# Percentage for dropping column:  80 %
#
# Not null rows before cleaning:
# Country 	 11374 	( 100.0 %)
# Competition 	 11374 	( 100.0 %)
# Season 	 11374 	( 100.0 %)
# Div 	 11374 	( 100.0 %)
# Date 	 11374 	( 100.0 %)
# HomeTeam 	 11374 	( 100.0 %)
# AwayTeam 	 11374 	( 100.0 %)
# FTR 	 11374 	( 100.0 %)
# B365H 	 11360 	( 99.88 %)
# B365D 	 11360 	( 99.88 %)
# B365A 	 11360 	( 99.88 %)
# BWH 	 11362 	( 99.89 %)
# BWD 	 11362 	( 99.89 %)
# BWA 	 11362 	( 99.89 %)
# IWH 	 11344 	( 99.74 %)
# IWD 	 11344 	( 99.74 %)
# IWA 	 11340 	( 99.7 %)
# LBH 	 7694 	( 67.65 %)
# LBD 	 7694 	( 67.65 %)
# LBA 	 7698 	( 67.68 %)
# VCH 	 11356 	( 99.84 %)
# VCD 	 11356 	( 99.84 %)
# VCA 	 11356 	( 99.84 %)
# WHH 	 11358 	( 99.86 %)
# WHD 	 11358 	( 99.86 %)
# WHA 	 11358 	( 99.86 %)
# Divergence 	 11374 	( 100.0 %)
#
# Dropped columns: ['LBH', 'LBD', 'LBA']
# Not null rows after cleaning:  11304 	( 99.38 %)
# Final columns: ['Country', 'Competition', 'Season', 'Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'VCH', 'VCD', 'VCA', 'WHH', 'WHD', 'WHA', 'Divergence']
#
#   - Calculating Bets Houses Cols
# Potential bets houses: ['B365', 'BS', 'BW', 'GB', 'IW', 'LB', 'SB', 'SJ', 'VC', 'WH']
# Bets houses selected : ['B365', 'BW', 'IW', 'VC', 'WH']
# Bets houses columns  : ['B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'VCH', 'VCD', 'VCA', 'WHH', 'WHD', 'WHA']
#
#   - Creating vector with label and features for training
# +------------------------------------------------------------------------+-----+
# |features                                                                |label|
# +------------------------------------------------------------------------+-----+
# |[1.12,9.0,19.0,1.1,9.25,19.0,1.12,9.0,20.0,1.09,10.0,29.0,1.11,9.0,21.0]|1.0  |
# |[1.9,3.6,4.0,1.83,3.4,4.33,1.8,3.6,4.5,1.85,3.6,4.3,1.85,3.4,4.4]       |1.0  |
# |[1.72,3.79,4.75,1.67,3.9,4.75,1.6,4.0,5.5,1.7,3.9,4.8,1.67,4.0,4.8]     |0.0  |
# |[1.5,4.33,6.5,1.48,4.1,6.75,1.55,4.0,6.2,1.5,4.5,6.25,1.5,4.4,6.0]      |0.0  |
# |[1.9,3.29,4.5,1.91,3.2,4.6,1.9,3.5,4.1,1.91,3.25,4.6,1.95,3.2,4.33]     |0.0  |
# +------------------------------------------------------------------------+-----+
# only showing top 5 rows
#
#
#   - Calculating prediction
# Rows: 21
# +-------+-----------+---------+---+-------------------+----------+--------+---+-----+-----+-----+----+----+----+----+---+----+----+----+----+----+----+----+----+---+----+------------------+-----+------------------------------------------------------------------------+------------------------------------------------------------+---------------------------------------------------------------+----------+
# |Country|Competition|Season   |Div|Date               |HomeTeam  |AwayTeam|FTR|B365H|B365D|B365A|BWH |BWD |BWA |IWH |IWD|IWA |LBH |LBD |LBA |VCH |VCD |VCA |WHH |WHD|WHA |Divergence        |label|features                                                                |rawPrediction                                               |probability                                                    |prediction|
# +-------+-----------+---------+---+-------------------+----------+--------+---+-----+-----+-----+----+----+----+----+---+----+----+----+----+----+----+----+----+---+----+------------------+-----+------------------------------------------------------------------------+------------------------------------------------------------+---------------------------------------------------------------+----------+
# |Spain  |Primera    |2017-2018|SP1|2018-11-02 00:00:00|Barcelona |Getafe  |D  |1.12 |9.0  |19.0 |1.1 |9.25|19.0|1.12|9.0|20.0|1.11|9.5 |19.0|1.09|10.0|29.0|1.11|9.0|21.0|37.00787401574803 |1.0  |[1.12,9.0,19.0,1.1,9.25,19.0,1.12,9.0,20.0,1.09,10.0,29.0,1.11,9.0,21.0]|[-399.52432110884683,-416.48492969670986,-440.0368356320239]|[0.9999999569372994,4.306270055315782E-8,2.544711051124989E-18]|0.0       |
# |Spain  |Primera    |2017-2018|SP1|2018-11-02 00:00:00|Celta     |Espanol |D  |1.9  |3.6  |4.0  |1.83|3.4 |4.33|1.8 |3.6|4.5 |1.85|3.4 |4.2 |1.85|3.6 |4.3 |1.85|3.4|4.4 |6.723668869024502 |1.0  |[1.9,3.6,4.0,1.83,3.4,4.33,1.8,3.6,4.5,1.85,3.6,4.3,1.85,3.4,4.4]       |[-129.2217898345514,-130.34206334078416,-132.71555469706323]|[0.7371495535670863,0.24045123103959282,0.022399215393320918]  |0.0       |
# |Spain  |Primera    |2017-2018|SP1|2018-11-02 00:00:00|Sevilla   |Girona  |H  |1.72 |3.79 |4.75 |1.67|3.9 |4.75|1.6 |4.0|5.5 |1.7 |3.75|4.75|1.7 |3.9 |4.8 |1.67|4.0|4.8 |12.436115843270867|0.0  |[1.72,3.79,4.75,1.67,3.9,4.75,1.6,4.0,5.5,1.7,3.9,4.8,1.67,4.0,4.8]     |[-139.04394604412724,-140.8809465689937,-144.19560109118166]|[0.8583069730921811,0.13672358885464955,0.004969438053169463]  |0.0       |
# |Spain  |Primera    |2017-2018|SP1|2018-11-02 00:00:00|Valencia  |Levante |H  |1.5  |4.33 |6.5  |1.48|4.1 |6.75|1.55|4.0|6.2 |1.5 |4.25|6.0 |1.5 |4.5 |6.25|1.5 |4.4|6.0 |7.427055702917751 |0.0  |[1.5,4.33,6.5,1.48,4.1,6.75,1.55,4.0,6.2,1.5,4.5,6.25,1.5,4.4,6.0]      |[-157.85718645058796,-161.1626785277867,-166.36878562564857]|[0.9644296367045327,0.03537639533746718,1.9396795800015882E-4] |0.0       |
# |Spain  |Primera    |2017-2018|SP1|2018-11-03 00:00:00|Ath Bilbao|Leganes |H  |1.9  |3.29 |4.5  |1.91|3.2 |4.6 |1.9 |3.5|4.1 |1.91|3.1 |4.5 |1.91|3.25|4.6 |1.95|3.2|4.33|7.622981599699575 |0.0  |[1.9,3.29,4.5,1.91,3.2,4.6,1.9,3.5,4.1,1.91,3.25,4.6,1.95,3.2,4.33]     |[-128.63353256067023,-129.8202558920819,-132.25906481698857]|[0.7508326838362129,0.22916894997891624,0.019998366184870844]  |0.0       |
# +-------+-----------+---------+---+-------------------+----------+--------+---+-----+-----+-----+----+----+----+----+---+----+----+----+----+----+----+----+----+---+----+------------------+-----+------------------------------------------------------------------------+------------------------------------------------------------+---------------------------------------------------------------+----------+
# only showing top 5 rows
#
#
#  - Reformating columns
# +-----------+-------------+----------+----------+-----+--------+--------+--------+
# |Competition|     HomeTeam|  AwayTeam|Prediction|Label|HomeProb|DrawProb|AwayProb|
# +-----------+-------------+----------+----------+-----+--------+--------+--------+
# |    Primera|    Barcelona|    Getafe|       0.0|  1.0|   99.99|     0.0|     0.0|
# |    Primera|        Celta|   Espanol|       0.0|  1.0|   73.71|   24.04|    2.23|
# |    Primera|      Sevilla|    Girona|       0.0|  0.0|   85.83|   13.67|    0.49|
# |    Primera|     Valencia|   Levante|       0.0|  0.0|   96.44|    3.53|    0.01|
# |    Primera|   Ath Bilbao|   Leganes|       0.0|  0.0|   75.08|   22.91|    1.99|
# |    Primera|   Ath Madrid|     Celta|       0.0|  0.0|   99.31|    0.68|     0.0|
# |    Primera|      Espanol|  Sociedad|       2.0|  0.0|    6.42|   30.46|    63.1|
# |    Primera|   Las Palmas|Villarreal|       2.0|  2.0|    0.53|   10.14|   89.32|
# |    Segunda|     Albacete| Gimnastic|       0.0|  2.0|   71.05|   26.02|    2.92|
# |    Segunda|       Huesca|   Leonesa|       0.0|  0.0|   95.91|    4.05|    0.02|
# |    Segunda|Reus Deportiu|     Lorca|       0.0|  0.0|    68.9|   27.61|    3.48|
# |    Segunda|     Tenerife|   Cordoba|       0.0|  0.0|   87.31|   12.26|    0.41|
# |    Segunda|    Vallecano| Sevilla B|       0.0|  0.0|   99.48|    0.51|     0.0|
# |    Segunda|     Zaragoza|      Lugo|       0.0|  0.0|    66.6|   29.28|     4.1|
# |    Segunda|     Albacete|   Osasuna|       1.0|  1.0|   18.09|   41.68|   40.22|
# |    Segunda|  Barcelona B|  Numancia|       1.0|  1.0|   18.84|   42.01|   39.13|
# |    Segunda|      Cordoba|      Lugo|       0.0|  0.0|   68.11|   28.25|    3.63|
# |    Segunda|Reus Deportiu|    Huesca|       2.0|  1.0|    4.37|   25.78|   69.84|
# |    Segunda|     Sp Gijon|   Leonesa|       0.0|  0.0|   95.35|     4.6|    0.03|
# |    Segunda|     Zaragoza|     Lorca|       0.0|  0.0|   97.79|     2.2|     0.0|
# +-----------+-------------+----------+----------+-----+--------+--------+--------+
# only showing top 20 rows

# %%
prediction = calcWeekPrediction(modelRecent, dfrecent, "Spain", "2018-11-01", "2018-11-07")
print ("Week prediction:")
prediction.show(50)
print ("Prediction and Label: Home win: 0, Draw: 1, Away win: 2")
# Out:
# Week prediction:
# +-----------+-------------+----------+----------+-----+--------+--------+--------+
# |Competition|     HomeTeam|  AwayTeam|Prediction|Label|HomeProb|DrawProb|AwayProb|
# +-----------+-------------+----------+----------+-----+--------+--------+--------+
# |    Primera|    Barcelona|    Getafe|       0.0|  1.0|   99.99|     0.0|     0.0|
# |    Primera|        Celta|   Espanol|       0.0|  1.0|   73.71|   24.04|    2.23|
# |    Primera|      Sevilla|    Girona|       0.0|  0.0|   85.83|   13.67|    0.49|
# |    Primera|     Valencia|   Levante|       0.0|  0.0|   96.44|    3.53|    0.01|
# |    Primera|   Ath Bilbao|   Leganes|       0.0|  0.0|   75.08|   22.91|    1.99|
# |    Primera|   Ath Madrid|     Celta|       0.0|  0.0|   99.31|    0.68|     0.0|
# |    Primera|      Espanol|  Sociedad|       2.0|  0.0|    6.42|   30.46|    63.1|
# |    Primera|   Las Palmas|Villarreal|       2.0|  2.0|    0.53|   10.14|   89.32|
# |    Segunda|     Albacete| Gimnastic|       0.0|  2.0|   71.05|   26.02|    2.92|
# |    Segunda|       Huesca|   Leonesa|       0.0|  0.0|   95.91|    4.05|    0.02|
# |    Segunda|Reus Deportiu|     Lorca|       0.0|  0.0|    68.9|   27.61|    3.48|
# |    Segunda|     Tenerife|   Cordoba|       0.0|  0.0|   87.31|   12.26|    0.41|
# |    Segunda|    Vallecano| Sevilla B|       0.0|  0.0|   99.48|    0.51|     0.0|
# |    Segunda|     Zaragoza|      Lugo|       0.0|  0.0|    66.6|   29.28|     4.1|
# |    Segunda|     Albacete|   Osasuna|       1.0|  1.0|   18.09|   41.68|   40.22|
# |    Segunda|  Barcelona B|  Numancia|       1.0|  1.0|   18.84|   42.01|   39.13|
# |    Segunda|      Cordoba|      Lugo|       0.0|  0.0|   68.11|   28.25|    3.63|
# |    Segunda|Reus Deportiu|    Huesca|       2.0|  1.0|    4.37|   25.78|   69.84|
# |    Segunda|     Sp Gijon|   Leonesa|       0.0|  0.0|   95.35|     4.6|    0.03|
# |    Segunda|     Zaragoza|     Lorca|       0.0|  0.0|   97.79|     2.2|     0.0|
# |    Segunda|        Lorca|  Numancia|       2.0|  0.0|    0.09|    4.38|   95.51|
# +-----------+-------------+----------+----------+-----+--------+--------+--------+
#
# Prediction and Label: Home win: 0, Draw: 1, Away win: 2
