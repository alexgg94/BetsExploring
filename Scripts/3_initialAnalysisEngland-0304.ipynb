# %%
# Preliminar original data analysis

# In this part we will describe the original information in some source files

# %%
import json
import os.path
import sys
import csv
import numpy as np
import pandas as pd

# %%
url="../Data/Raw/Main/England/Championship_0304.csv"
parse_dates=["Date"]
ds = pd.read_csv(url, parse_dates=parse_dates)

# %%
ds.shape
# Out:
# (552, 57)

# %%
ds.head(5)
# Out:
#   Div       Date  HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0  E1 2003-09-08  Bradford         Norwich     2     2   D     0     1   A
# 1  E1 2003-09-08   Burnley  Crystal Palace     2     3   A     2     2   D
# 2  E1 2003-09-08     Derby           Stoke     0     3   A     0     2   A
# 3  E1 2003-09-08   Ipswich         Reading     1     1   D     0     0   D
# 4  E1 2003-09-08  Millwall           Wigan     2     0   H     0     0   D
#
#     ...   B365<2.5  GBAHH  GBAHA  GBAH  LBAHH  LBAHA  LBAH  B365AHH  B365AHA  \
# 0   ...       1.80    1.8   2.00  0.00   2.05   1.80 -0.25     1.80     2.05
# 1   ...       2.00    2.0   1.80 -0.25   2.05   1.80 -0.25     2.05     1.80
# 2   ...       1.80    1.8   2.00 -0.50   1.85   2.00 -0.50     1.85     2.00
# 3   ...       1.83    1.9   1.88 -0.50   1.90   1.95 -0.50     2.00     1.85
# 4   ...       1.83    2.0   1.80 -0.50   1.95   1.90 -0.50     2.10     1.75
#
#    B365AH
# 0    0.00
# 1   -0.25
# 2   -0.50
# ...

# %%
ds.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  552.000000  552.000000  552.000000  552.000000  552.000000  552.000000
# mean     1.478261    1.121377    0.655797    0.487319   12.344203    9.561594
# std      1.247676    1.071718    0.837637    0.735305    4.741331    4.178830
# min      0.000000    0.000000    0.000000    0.000000    2.000000    1.000000
# 25%      1.000000    0.000000    0.000000    0.000000    9.000000    6.000000
# 50%      1.000000    1.000000    0.000000    0.000000   12.000000    9.000000
# 75%      2.000000    2.000000    1.000000    1.000000   15.000000   12.000000
# max      6.000000    6.000000    5.000000    3.000000   31.000000   27.000000
#
#               HST         AST         HF          AF     ...        B365<2.5  \
# count  552.000000  552.000000  552.00000  552.000000     ...      511.000000
# mean     6.711957    5.222826   12.21558   12.853261     ...        1.858395
# ...
